# %% [markdown]
# 수정사항
# - augmentation 조정

# %%
# 시작 전에 GPU로 바꿔주기

# %% [markdown]
# # CNN 모델 만들고, ImageDataGenerator을 이용해서 학습 진행하기

# %%
# 필요한 module import
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Google Drive 접근 = 구글 마운트하기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## ImageDataGenerator 만들기 (rescale만 이용 / 다른 augmentation 제외)

# %%
# 이미지들이 있는 train, validation 폴더 가져오기
# 이 이미지들은 본인의 Local 파일에 각각 저장되어 있어야한다
# FinalProject에 있는 infant라는 폴더를 본인의 드라이브에 넣기!

train_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/train'
validation_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/valid'

# %%
# ImageDataGenerator 객체 생성

train_datagen = ImageDataGenerator(rescale=1/255) # 0 or 1의 값이 나올 수 있도록 255로 나누어 준다
validation_datagen=ImageDataGenerator(rescale=1/255)


# ImageDataGenerator 객체 세부 설정
# 넌 이렇게 동작해야해! 라고 세부 세팅을 해준다

train_generator = train_datagen.flow_from_directory( # train_datagen.flow_from_directory() 특정 폴더로부터 generator을 뽑아내는 객체를 하나 만든다
    train_dir, # target directory
    classes=['positive', 'neutral', 'negative'], # train 안에 있는 폴더를 내가 원하는 순서대로 준다 (positive -> neutral -> negative)
                                                 # label(target) 지정, list의 순서대로 지정하기!
                                                 # 만약 생략되면 폴더 순서는 오름차순으로 지정된다.
    target_size=(150, 150), #image resize
    batch_size=5, # 한번에 20개의 이미지를 가져온다
                   # label에 상관없이 이미지를 가져온다
    class_mode='categorical' # 다중분류 : categorical, 이진분류 : binary
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    classes=['positive', 'neutral', 'negative'],
    target_size=(150, 150), # 평가 데이터이기 떄문에 size를 똑같이 가져와야 한다
    batch_size=5,
    class_mode='categorical'
)

# Found 330 images belonging to 3 classes.
# Found 65 images belonging to 3 classes.
# Out:
# Found 330 images belonging to 3 classes.
# Found 65 images belonging to 3 classes.

# %% [markdown]
# ## CNN Model 구현

# %%
# 필터의 개수는 앞쪽에서 뒤쪽으로 갈 수록 많아지는 것이 좋다
# 필터의 크기(kernel_size)는 3x3 을 보통 쓴다

model = Sequential()

model.add(Conv2D(filters=32,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu',
                 input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))  # 여기서는 input_shape을 빼주어야한다
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=256,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# model.summary() # 중간에 확인해주고 넘어가기

model.add(Flatten())
model.add(Dropout(rate=0.5))
model.add(Dense(units=256,
                activation='relu'))
model.add(Dense(units=3,
                activation='softmax'))

model.summary()


# Total params: 3600707 (13.74 MB)
# Trainable params: 3600707 (13.74 MB) -> 학습이 가능한, 값이 바뀌는 파라미터
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_8 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_9 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 34, 34, 128)       73856
#
#  max_pooling2d_10 (MaxPooli  (None, 17, 17, 128)       0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 15, 15, 256)       295168
#
#  max_pooling2d_11 (MaxPooli  (None, 7, 7, 256)         0
#  ng2D)
#
#  flatten_2 (Flatten)         (None, 12544)             0
#
#  dropout_2 (Dropout)         (None, 12544)             0
#
#  dense_4 (Dense)             (None, 256)               3211520
#
#  dense_5 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 3600707 (13.74 MB)
# Trainable params: 3600707 (13.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# model 학습 설정


model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


# model checkpoint 확인
model_cp = ModelCheckpoint(filepath='infantface_checkpoint.ckpt', # 임시로 제공 받은 runtime disk에 파일이 만들어진다. 계산된 가중치를 저장해놓자
                           save_weights_only=True,
                           save_best_only=True,
                           monitor='val_loss',
                           verbose=1)

# model earlystopping 확인(조기 종료는 언제할까요?)
model_es = EarlyStopping(monitor='val_loss',
                         patience=5,
                         verbose=1,
                         restore_best_weights=True)


history = model.fit(train_generator,
                    steps_per_epoch=66,  # 1 epoch 당 몇 번 수행할지 정해주어야 한다. 이것도 직접 계산 330/5 = 66
                    epochs=100,
                    verbose=1,
                    #validation_split=0.3 이라고 썼었는데, 이제 validation_data가 따로 있기 때문에
                    validation_data=validation_generator,
                    validation_steps=13, # 계산해서 넣어주어야 한다
                                         # 즉, 65/5 = 13
                    callbacks=[model_cp, model_es])


model.save('./infantface_cnn_model.h5') # 학습이 끝나면, 우리 모델에 대해서 한 번에 딱 저장
# 저장하는 방법 2가지
# 1. checkpoint와 callback을 이용해서 epoch마다 저장해준다
# 2. 모델에 있어서 한 번에 저장


# 위 처럼 만들고 model 학습 진행 (shift+enter)
# Out:
# Epoch 1/100
# 65/66 [============================>.] - ETA: 0s - loss: 1.1069 - accuracy: 0.3785
# Epoch 1: val_loss improved from inf to 1.08086, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 59ms/step - loss: 1.1076 - accuracy: 0.3758 - val_loss: 1.0809 - val_accuracy: 0.4000
# Epoch 2/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0821 - accuracy: 0.4121
# Epoch 2: val_loss improved from 1.08086 to 1.07613, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 48ms/step - loss: 1.0821 - accuracy: 0.4121 - val_loss: 1.0761 - val_accuracy: 0.4000
# Epoch 3/100
# 65/66 [============================>.] - ETA: 0s - loss: 1.0550 - accuracy: 0.4246
# Epoch 3: val_loss improved from 1.07613 to 1.00665, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 50ms/step - loss: 1.0534 - accuracy: 0.4242 - val_loss: 1.0066 - val_accuracy: 0.4308
# Epoch 4/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.9310 - accuracy: 0.5446
# Epoch 4: val_loss improved from 1.00665 to 0.88445, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 4s 62ms/step - loss: 0.9334 - accuracy: 0.5455 - val_loss: 0.8844 - val_accuracy: 0.6308
# Epoch 5/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7999 - accuracy: 0.6758
# Epoch 5: val_loss improved from 0.88445 to 0.86147, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 50ms/step - loss: 0.7999 - accuracy: 0.6758 - val_loss: 0.8615 - val_accuracy: 0.6154
# Epoch 6/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7188 - accuracy: 0.6879
# Epoch 6: val_loss did not improve from 0.86147
# 66/66 [==============================] - 3s 48ms/step - loss: 0.7188 - accuracy: 0.6879 - val_loss: 0.8773 - val_accuracy: 0.5692
# Epoch 7/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6263 - accuracy: 0.7455
# Epoch 7: val_loss improved from 0.86147 to 0.85314, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 93ms/step - loss: 0.6263 - accuracy: 0.7455 - val_loss: 0.8531 - val_accuracy: 0.6154
# Epoch 8/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5720 - accuracy: 0.7636
# Epoch 8: val_loss improved from 0.85314 to 0.80826, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 4s 57ms/step - loss: 0.5720 - accuracy: 0.7636 - val_loss: 0.8083 - val_accuracy: 0.6462
# Epoch 9/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5148 - accuracy: 0.8121
# Epoch 9: val_loss did not improve from 0.80826
# 66/66 [==============================] - 3s 50ms/step - loss: 0.5148 - accuracy: 0.8121 - val_loss: 0.8317 - val_accuracy: 0.6615
# Epoch 10/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4701 - accuracy: 0.8152
# Epoch 10: val_loss improved from 0.80826 to 0.74382, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 4s 56ms/step - loss: 0.4701 - accuracy: 0.8152 - val_loss: 0.7438 - val_accuracy: 0.6923
# Epoch 11/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4028 - accuracy: 0.8303
# Epoch 11: val_loss improved from 0.74382 to 0.68358, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 48ms/step - loss: 0.4028 - accuracy: 0.8303 - val_loss: 0.6836 - val_accuracy: 0.7231
# Epoch 12/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 0.8909
# Epoch 12: val_loss improved from 0.68358 to 0.65604, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 50ms/step - loss: 0.3104 - accuracy: 0.8909 - val_loss: 0.6560 - val_accuracy: 0.7231
# Epoch 13/100
# 66/66 [==============================] - ETA: 0s - loss: 0.2626 - accuracy: 0.9182
# Epoch 13: val_loss did not improve from 0.65604
# 66/66 [==============================] - 5s 73ms/step - loss: 0.2626 - accuracy: 0.9182 - val_loss: 0.6733 - val_accuracy: 0.7385
# Epoch 14/100
# 66/66 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.9091
# Epoch 14: val_loss improved from 0.65604 to 0.65554, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 49ms/step - loss: 0.2614 - accuracy: 0.9091 - val_loss: 0.6555 - val_accuracy: 0.6923
# Epoch 15/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.2073 - accuracy: 0.9354
# Epoch 15: val_loss improved from 0.65554 to 0.64369, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 50ms/step - loss: 0.2054 - accuracy: 0.9364 - val_loss: 0.6437 - val_accuracy: 0.7692
# Epoch 16/100
# 66/66 [==============================] - ETA: 0s - loss: 0.2201 - accuracy: 0.9333
# Epoch 16: val_loss improved from 0.64369 to 0.53209, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 4s 53ms/step - loss: 0.2201 - accuracy: 0.9333 - val_loss: 0.5321 - val_accuracy: 0.7846
# Epoch 17/100
# 66/66 [==============================] - ETA: 0s - loss: 0.1695 - accuracy: 0.9364
# Epoch 17: val_loss did not improve from 0.53209
# 66/66 [==============================] - 4s 62ms/step - loss: 0.1695 - accuracy: 0.9364 - val_loss: 0.6046 - val_accuracy: 0.7385
# Epoch 18/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.9446
# Epoch 18: val_loss did not improve from 0.53209
# 66/66 [==============================] - 3s 47ms/step - loss: 0.1647 - accuracy: 0.9455 - val_loss: 0.5333 - val_accuracy: 0.8154
# Epoch 19/100
# 66/66 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9788
# Epoch 19: val_loss did not improve from 0.53209
# 66/66 [==============================] - 3s 47ms/step - loss: 0.1027 - accuracy: 0.9788 - val_loss: 0.5761 - val_accuracy: 0.8154
# Epoch 20/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0833 - accuracy: 0.9754
# Epoch 20: val_loss improved from 0.53209 to 0.45666, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 52ms/step - loss: 0.0859 - accuracy: 0.9727 - val_loss: 0.4567 - val_accuracy: 0.8000
# Epoch 21/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.1224 - accuracy: 0.9600
# Epoch 21: val_loss did not improve from 0.45666
# 66/66 [==============================] - 4s 53ms/step - loss: 0.1217 - accuracy: 0.9606 - val_loss: 0.5481 - val_accuracy: 0.8000
# Epoch 22/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0587 - accuracy: 0.9877
# Epoch 22: val_loss did not improve from 0.45666
# 66/66 [==============================] - 3s 47ms/step - loss: 0.0584 - accuracy: 0.9879 - val_loss: 0.4747 - val_accuracy: 0.9077
# Epoch 23/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0598 - accuracy: 0.9877
# Epoch 23: val_loss did not improve from 0.45666
# 66/66 [==============================] - 3s 48ms/step - loss: 0.0598 - accuracy: 0.9879 - val_loss: 0.5066 - val_accuracy: 0.8154
# Epoch 24/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0624 - accuracy: 0.9846
# Epoch 24: val_loss improved from 0.45666 to 0.43446, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 4s 63ms/step - loss: 0.0616 - accuracy: 0.9848 - val_loss: 0.4345 - val_accuracy: 0.9077
# Epoch 25/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0606 - accuracy: 0.9815
# Epoch 25: val_loss improved from 0.43446 to 0.40436, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 4s 54ms/step - loss: 0.0600 - accuracy: 0.9818 - val_loss: 0.4044 - val_accuracy: 0.8769
# Epoch 26/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9908
# Epoch 26: val_loss did not improve from 0.40436
# 66/66 [==============================] - 3s 49ms/step - loss: 0.0347 - accuracy: 0.9909 - val_loss: 0.4471 - val_accuracy: 0.8769
# Epoch 27/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.9938
# Epoch 27: val_loss improved from 0.40436 to 0.31777, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 47ms/step - loss: 0.0293 - accuracy: 0.9939 - val_loss: 0.3178 - val_accuracy: 0.9231
# Epoch 28/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0413 - accuracy: 0.9815
# Epoch 28: val_loss did not improve from 0.31777
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0407 - accuracy: 0.9818 - val_loss: 0.4947 - val_accuracy: 0.8769
# Epoch 29/100
# 66/66 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9848
# Epoch 29: val_loss did not improve from 0.31777
# 66/66 [==============================] - 4s 59ms/step - loss: 0.0475 - accuracy: 0.9848 - val_loss: 0.5891 - val_accuracy: 0.8000
# Epoch 30/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0411 - accuracy: 0.9877
# Epoch 30: val_loss did not improve from 0.31777
# 66/66 [==============================] - 3s 47ms/step - loss: 0.0409 - accuracy: 0.9879 - val_loss: 0.4694 - val_accuracy: 0.8923
# Epoch 31/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0371 - accuracy: 0.9877
# Epoch 31: val_loss did not improve from 0.31777
# 66/66 [==============================] - 3s 47ms/step - loss: 0.0368 - accuracy: 0.9879 - val_loss: 0.4170 - val_accuracy: 0.8923
# Epoch 32/100
# 66/66 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9939
# Epoch 32: val_loss did not improve from 0.31777
# Restoring model weights from the end of the best epoch: 27.
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0269 - accuracy: 0.9939 - val_loss: 0.3201 - val_accuracy: 0.8769
# Epoch 32: early stopping
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# 마지막 결과값
# 66/66 [==============================] - 3s 45ms/step - loss: 0.0360 - accuracy: 0.9970 - val_loss: 0.5185 - val_accuracy: 0.8769
# Epoch 28: early stopping

# 기준을 어떻게 세워야 하는가?
# 1. loss, val_loss
# 기준 : 손실은 모델이 실제 값과 예측 값 간의 차이를 나타내므로, "낮을수록 좋다"
# 해석 : 훈련 손실과 검증 손실이 둘 다 감소하는 것은, 모델이 데이터에 잘 적함되고 있다는 것을 나타낸다.
#       그러나, 두 손실이 크게 차이나는 경우에는 과적합이 발생할 가능성이 있으므로 주의가 필요
# 2. accuracy, val_accuracy
# 기준 : 모델이 올바르게 분류한 샘플의 비율을 나타내므로, "높을수록 좋다"
# 해석 : 훈련 정확도와 검증 정확도가 둘 다 증가하는 것은 모델이 데이터를 잘 이해하고 일반화되고 있다는 것을 나타냅니다.
#       과적합이 발생하지 않도록 주의해야 합니다.

# %%
# 결과 그래프를 그려보아요!
# 이때, 그래프를 해석할 줄 알아야 한다.
# 기준 : loss(훈련 손실)과 val_loss(검증 손실) 차이가 크지 않고,
#       accarcy(훈련 정확도) val_accuracy(검증 정확도)가 유사한지 확인해봐야한다.
# 해석 : 이러한 관계가 유지되면 모델이 새로운 데이터에 대해 일반화할 수 있음을 나타내며, 과적합이 발생하지 않았음을 이야기함.
# 만약, val_loss의 선인 파란선이 중간에 상승하는 모습을 보인다면 = Overfitting --> 차이가 생기기 시작하기 때문!

import matplotlib.pyplot as plt
fig = plt.figure()

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(history.history['loss'], color='r')
ax1.plot(history.history['val_loss'], color='b')

ax2.plot(history.history['accuracy'], color='r')
ax2.plot(history.history['val_accuracy'], color='b')

plt.tight_layout()
plt.show()

# %%
# Early Stopping 및 Model Checkpoint 콜백 활용
# 어떻게?
# Early Stopping과 Model Checkpoint 콜백을 사용하여 검증 손실이 더 이상 감소하지 않거나 증가하기 시작할 때 학습을 조기 종료하고 최적의 모델을 저장합니다.
# 해석
# 이는 모델이 더 이상 개선되지 않고 있거나 과적합이 시작될 때 학습을 중단하여 일반화된 모델을 얻을 수 있도록 도와줍니다.

# %% [markdown]
# **OverFitting 줄이는 방법**
#
#
# 1. Feature의 개수 줄이기
# 2. 규제(L1, L2)
# 3. Dropout
#
# 가장 중요한 방법은!
# 4. Data가 많으면 된다
#    Image를 증식(Augmenation)을 이용해서 학습하면 되겠다!
#
#    but, 증식 데이터는 '코드'를 구현해야 한다.
#
#    이 코드는 ImageDataGenerator가 제공한다

# %% [markdown]
# ## ImageDataGenerator을 이용해 overfitting 해결하기 (rescale을 비롯한 다른 augmentation 활용)

# %% [markdown]
# ### 이미지 1장을 이용해 증식 사용해보기

# %%
# 필요한 module import
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
# 원하는 증식 정도를 모두 적어주기
datagen = ImageDataGenerator(rotation_range=20, # 회전 각도를 주어서 이미지를 변형
                             width_shift_range=0.1, # 10% 정도의 비율의 범위 내에서만 이동해라
                             height_shift_range=0.1,
                             shear_range=0.1,
                             zoom_range=0.2,
                             horizontal_flip=True,
                             fill_mode='nearest' # 이미지가 생길 수 있는 빈 공간이 생기는데 그 빈공간을 'nearest'로 근처에 있는 픽셀의 값으로 채워라)
                             )

# %%
# 원하는 이미지 1장을 증식해보기!
img = image.load_img('/content/drive/MyDrive/KOSA3/project/data/infantface/train/positive/Pos1.bmp',
                     target_size=(150,150))

# 원래는 numpy array가 나와야 함
# 확인
print(type(img)) # <class 'PIL.Image.Image'> --> numpy array가 아니기 때문에 이로 바꾸어주어야함

# numpy array로 바꿔줌
x = image.img_to_array(img)
print(type(x), x.shape)  # <class 'numpy.ndarray'> (150, 150, 3)
# 현재 이미지가 1장이다. 이 이미지에 대해서 ImageDataGenerator를 이용해서
# Augmentation(증식)된 이미지를 뽑을것이다.

# 그런데 ImageDataGenerator은 여러장의 이미지를 추출하는 거라서
# 기본적으로 4차원이 필요하다 (하지만, 현재 가지고 있는 것은 3차원이다)
x = x.reshape((1,) + x.shape) # x라는 4차원 데이터를 준비
print(x.shape)  # (1, 150, 150, 3)



# 증식된 이미지 20장을 그려보자
# 이미지의 개수를 확 늘려서(데이터의 개수를 늘려서)
# overfitting을 줄이자!

fig = plt.figure()
axs = []

for i in range(20):
    axs.append(fig.add_subplot(4,5,i+1))

idx = 0
for batch in datagen.flow(x, batch_size=1):
    axs[idx].imshow(image.array_to_img(batch[0]))
    idx += 1
    if idx % 20 == 0:
        break;
# Out:
# <class 'PIL.Image.Image'>
# <class 'numpy.ndarray'> (150, 150, 3)
# (1, 150, 150, 3)

# %% [markdown]
# ### 증식을 이용해 학습 진행해보기

# %%
# 필요한 module import
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# ImageDataGenerator 생성

#  dir 불러오기
train_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/train'
validation_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/valid'

# ImageDataGenerator를 생성(객체 생성)
train_datagen = ImageDataGenerator(rescale=1/255,
                                   rotation_range=20,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   shear_range=0.1,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   fill_mode='nearest')
validation_datagen = ImageDataGenerator(rescale=1/255)

# ImageDataGenerator 객체 세부 설정
# 넌 이렇게 동작해야해! 라고 세부 세팅을 해준다

train_generator = train_datagen.flow_from_directory(
    train_dir,
    classes=['positive', 'neutral', 'negative'],
    target_size=(150, 150),
    batch_size=5,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    classes=['positive', 'neutral', 'negative'],
    target_size=(150, 150),
    batch_size=5,
    class_mode='categorical'
)
# Out:
# Found 330 images belonging to 3 classes.
# Found 65 images belonging to 3 classes.

# %%
# Model 구현
# 위에서 만든 Model과 똑같음 (copy&paste)

model = Sequential()

model.add(Conv2D(filters=32,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu',
                 input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=256,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dropout(rate=0.5))
model.add(Dense(units=256,
                activation='relu'))
model.add(Dense(units=3,
                activation='softmax'))

# %% [markdown]
# 수정한 것
# 1.  EarlyStopping의 patience 수를 높임
#     66/66 [==============================] - 5s 69ms/step - loss: 0.8461 - accuracy: 0.5939 - val_loss: 1.0182 - val_accuracy: 0.5846
# Epoch 6: early stopping
# -> 학습결과가 좋지 않아서
# 2. earlystopping을 없앰

# %%
# Model 학습 설정 및 진행

# model 학습 설정
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


# model checkpoint 확인
model_cp = ModelCheckpoint(filepath='infantface_checkpoint.ckpt',
                           save_weights_only=True,
                           save_best_only=True,
                           monitor='val_loss',
                           verbose=1)

# model earlystopping 확인(조기 종료는 언제할까요?)
model_es = EarlyStopping(monitor='val_loss',
                         patience=5,
                         verbose=1,
                         restore_best_weights=True)



history = model.fit(train_generator,
                    steps_per_epoch=66,
                    epochs=100,
                    verbose=1,
                    validation_data=validation_generator,
                    validation_steps=13,
                    callbacks=[model_cp])


model.save('./infantface_IDG_cnn_model.h5')
# Out:
# Epoch 1/100
# 66/66 [==============================] - ETA: 0s - loss: 1.1052 - accuracy: 0.3606
# Epoch 1: val_loss improved from inf to 1.09145, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 75ms/step - loss: 1.1052 - accuracy: 0.3606 - val_loss: 1.0914 - val_accuracy: 0.3385
# Epoch 2/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0943 - accuracy: 0.3667
# Epoch 2: val_loss improved from 1.09145 to 1.08538, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 84ms/step - loss: 1.0943 - accuracy: 0.3667 - val_loss: 1.0854 - val_accuracy: 0.4000
# Epoch 3/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0912 - accuracy: 0.3909
# Epoch 3: val_loss improved from 1.08538 to 1.07737, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 74ms/step - loss: 1.0912 - accuracy: 0.3909 - val_loss: 1.0774 - val_accuracy: 0.4000
# Epoch 4/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0908 - accuracy: 0.3879
# Epoch 4: val_loss did not improve from 1.07737
# 66/66 [==============================] - 6s 97ms/step - loss: 1.0908 - accuracy: 0.3879 - val_loss: 1.0794 - val_accuracy: 0.4000
# Epoch 5/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0909 - accuracy: 0.3909
# Epoch 5: val_loss did not improve from 1.07737
# 66/66 [==============================] - 6s 97ms/step - loss: 1.0909 - accuracy: 0.3909 - val_loss: 1.0807 - val_accuracy: 0.4000
# Epoch 6/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0850 - accuracy: 0.3879
# Epoch 6: val_loss improved from 1.07737 to 1.07397, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 10s 145ms/step - loss: 1.0850 - accuracy: 0.3879 - val_loss: 1.0740 - val_accuracy: 0.4000
# Epoch 7/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0819 - accuracy: 0.3788
# Epoch 7: val_loss improved from 1.07397 to 1.06603, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 72ms/step - loss: 1.0819 - accuracy: 0.3788 - val_loss: 1.0660 - val_accuracy: 0.3846
# Epoch 8/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0769 - accuracy: 0.4030
# Epoch 8: val_loss did not improve from 1.06603
# 66/66 [==============================] - 5s 74ms/step - loss: 1.0769 - accuracy: 0.4030 - val_loss: 1.0697 - val_accuracy: 0.4615
# Epoch 9/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0670 - accuracy: 0.4061
# Epoch 9: val_loss improved from 1.06603 to 1.04486, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 103ms/step - loss: 1.0670 - accuracy: 0.4061 - val_loss: 1.0449 - val_accuracy: 0.4308
# Epoch 10/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0520 - accuracy: 0.4061
# Epoch 10: val_loss improved from 1.04486 to 0.99605, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 73ms/step - loss: 1.0520 - accuracy: 0.4061 - val_loss: 0.9961 - val_accuracy: 0.4769
# Epoch 11/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0470 - accuracy: 0.4303
# Epoch 11: val_loss did not improve from 0.99605
# 66/66 [==============================] - 7s 104ms/step - loss: 1.0470 - accuracy: 0.4303 - val_loss: 1.0430 - val_accuracy: 0.4154
# Epoch 12/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0507 - accuracy: 0.3970
# Epoch 12: val_loss improved from 0.99605 to 0.98625, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 70ms/step - loss: 1.0507 - accuracy: 0.3970 - val_loss: 0.9863 - val_accuracy: 0.5538
# Epoch 13/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0131 - accuracy: 0.4758
# Epoch 13: val_loss improved from 0.98625 to 0.96531, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 88ms/step - loss: 1.0131 - accuracy: 0.4758 - val_loss: 0.9653 - val_accuracy: 0.5538
# Epoch 14/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0169 - accuracy: 0.4818
# Epoch 14: val_loss did not improve from 0.96531
# 66/66 [==============================] - 6s 85ms/step - loss: 1.0169 - accuracy: 0.4818 - val_loss: 1.0698 - val_accuracy: 0.4462
# Epoch 15/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0051 - accuracy: 0.4545
# Epoch 15: val_loss did not improve from 0.96531
# 66/66 [==============================] - 5s 71ms/step - loss: 1.0051 - accuracy: 0.4545 - val_loss: 0.9884 - val_accuracy: 0.5077
# Epoch 16/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9614 - accuracy: 0.5394
# Epoch 16: val_loss improved from 0.96531 to 0.94225, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 91ms/step - loss: 0.9614 - accuracy: 0.5394 - val_loss: 0.9423 - val_accuracy: 0.5385
# Epoch 17/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9824 - accuracy: 0.4939
# Epoch 17: val_loss improved from 0.94225 to 0.91620, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 87ms/step - loss: 0.9824 - accuracy: 0.4939 - val_loss: 0.9162 - val_accuracy: 0.5846
# Epoch 18/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9755 - accuracy: 0.5212
# Epoch 18: val_loss did not improve from 0.91620
# 66/66 [==============================] - 5s 68ms/step - loss: 0.9755 - accuracy: 0.5212 - val_loss: 1.0743 - val_accuracy: 0.4462
# Epoch 19/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9205 - accuracy: 0.5576
# Epoch 19: val_loss did not improve from 0.91620
# 66/66 [==============================] - 6s 87ms/step - loss: 0.9205 - accuracy: 0.5576 - val_loss: 0.9603 - val_accuracy: 0.5385
# Epoch 20/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9733 - accuracy: 0.5091
# Epoch 20: val_loss improved from 0.91620 to 0.91615, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 89ms/step - loss: 0.9733 - accuracy: 0.5091 - val_loss: 0.9162 - val_accuracy: 0.5846
# Epoch 21/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8778 - accuracy: 0.5879
# Epoch 21: val_loss improved from 0.91615 to 0.91591, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 73ms/step - loss: 0.8778 - accuracy: 0.5879 - val_loss: 0.9159 - val_accuracy: 0.6000
# Epoch 22/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9213 - accuracy: 0.5697
# Epoch 22: val_loss improved from 0.91591 to 0.90449, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 91ms/step - loss: 0.9213 - accuracy: 0.5697 - val_loss: 0.9045 - val_accuracy: 0.6000
# Epoch 23/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8850 - accuracy: 0.5697
# Epoch 23: val_loss did not improve from 0.90449
# 66/66 [==============================] - 5s 71ms/step - loss: 0.8850 - accuracy: 0.5697 - val_loss: 0.9331 - val_accuracy: 0.5538
# Epoch 24/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8599 - accuracy: 0.5697
# Epoch 24: val_loss did not improve from 0.90449
# 66/66 [==============================] - 6s 88ms/step - loss: 0.8599 - accuracy: 0.5697 - val_loss: 1.0682 - val_accuracy: 0.6308
# Epoch 25/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8624 - accuracy: 0.6152
# Epoch 25: val_loss improved from 0.90449 to 0.89193, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 96ms/step - loss: 0.8624 - accuracy: 0.6152 - val_loss: 0.8919 - val_accuracy: 0.6000
# Epoch 26/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7979 - accuracy: 0.6273
# Epoch 26: val_loss did not improve from 0.89193
# 66/66 [==============================] - 5s 74ms/step - loss: 0.7979 - accuracy: 0.6273 - val_loss: 1.0108 - val_accuracy: 0.6000
# Epoch 27/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7788 - accuracy: 0.6424
# Epoch 27: val_loss did not improve from 0.89193
# 66/66 [==============================] - 6s 91ms/step - loss: 0.7788 - accuracy: 0.6424 - val_loss: 0.9059 - val_accuracy: 0.5692
# Epoch 28/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8219 - accuracy: 0.6273
# Epoch 28: val_loss did not improve from 0.89193
# 66/66 [==============================] - 6s 89ms/step - loss: 0.8219 - accuracy: 0.6273 - val_loss: 0.9384 - val_accuracy: 0.5538
# Epoch 29/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8209 - accuracy: 0.6333
# Epoch 29: val_loss did not improve from 0.89193
# 66/66 [==============================] - 5s 71ms/step - loss: 0.8209 - accuracy: 0.6333 - val_loss: 0.9542 - val_accuracy: 0.5692
# Epoch 30/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7772 - accuracy: 0.6788
# Epoch 30: val_loss did not improve from 0.89193
# 66/66 [==============================] - 6s 94ms/step - loss: 0.7772 - accuracy: 0.6788 - val_loss: 0.9826 - val_accuracy: 0.6154
# Epoch 31/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6945 - accuracy: 0.6848
# Epoch 31: val_loss did not improve from 0.89193
# 66/66 [==============================] - 5s 70ms/step - loss: 0.6945 - accuracy: 0.6848 - val_loss: 1.0313 - val_accuracy: 0.6000
# Epoch 32/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7466 - accuracy: 0.6576
# Epoch 32: val_loss did not improve from 0.89193
# 66/66 [==============================] - 6s 88ms/step - loss: 0.7466 - accuracy: 0.6576 - val_loss: 1.0110 - val_accuracy: 0.5385
# Epoch 33/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7488 - accuracy: 0.6727
# Epoch 33: val_loss did not improve from 0.89193
# 66/66 [==============================] - 6s 84ms/step - loss: 0.7488 - accuracy: 0.6727 - val_loss: 1.0163 - val_accuracy: 0.6154
# Epoch 34/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7692 - accuracy: 0.6424
# Epoch 34: val_loss did not improve from 0.89193
# 66/66 [==============================] - 5s 70ms/step - loss: 0.7692 - accuracy: 0.6424 - val_loss: 1.0190 - val_accuracy: 0.5538
# Epoch 35/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7170 - accuracy: 0.6545
# Epoch 35: val_loss did not improve from 0.89193
# 66/66 [==============================] - 6s 87ms/step - loss: 0.7170 - accuracy: 0.6545 - val_loss: 0.9076 - val_accuracy: 0.5692
# Epoch 36/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6682 - accuracy: 0.7212
# Epoch 36: val_loss did not improve from 0.89193
# 66/66 [==============================] - 7s 111ms/step - loss: 0.6682 - accuracy: 0.7212 - val_loss: 0.9810 - val_accuracy: 0.6000
# Epoch 37/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6260 - accuracy: 0.7545
# Epoch 37: val_loss did not improve from 0.89193
# 66/66 [==============================] - 5s 77ms/step - loss: 0.6260 - accuracy: 0.7545 - val_loss: 1.1077 - val_accuracy: 0.5846
# Epoch 38/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.7091
# Epoch 38: val_loss did not improve from 0.89193
# 66/66 [==============================] - 6s 97ms/step - loss: 0.6935 - accuracy: 0.7091 - val_loss: 0.9650 - val_accuracy: 0.5692
# Epoch 39/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6821 - accuracy: 0.6697
# Epoch 39: val_loss did not improve from 0.89193
# 66/66 [==============================] - 5s 71ms/step - loss: 0.6821 - accuracy: 0.6697 - val_loss: 0.9701 - val_accuracy: 0.5538
# Epoch 40/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6375 - accuracy: 0.7455
# Epoch 40: val_loss did not improve from 0.89193
# 66/66 [==============================] - 7s 107ms/step - loss: 0.6375 - accuracy: 0.7455 - val_loss: 0.9775 - val_accuracy: 0.6154
# Epoch 41/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6608 - accuracy: 0.7121
# Epoch 41: val_loss improved from 0.89193 to 0.86282, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 73ms/step - loss: 0.6608 - accuracy: 0.7121 - val_loss: 0.8628 - val_accuracy: 0.6154
# Epoch 42/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6338 - accuracy: 0.6909
# Epoch 42: val_loss did not improve from 0.86282
# 66/66 [==============================] - 5s 71ms/step - loss: 0.6338 - accuracy: 0.6909 - val_loss: 1.0109 - val_accuracy: 0.6000
# Epoch 43/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.7303
# Epoch 43: val_loss did not improve from 0.86282
# 66/66 [==============================] - 7s 103ms/step - loss: 0.6223 - accuracy: 0.7303 - val_loss: 1.1072 - val_accuracy: 0.6154
# Epoch 44/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6493 - accuracy: 0.7091
# Epoch 44: val_loss did not improve from 0.86282
# 66/66 [==============================] - 5s 72ms/step - loss: 0.6493 - accuracy: 0.7091 - val_loss: 0.8658 - val_accuracy: 0.5846
# Epoch 45/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6210 - accuracy: 0.7242
# Epoch 45: val_loss did not improve from 0.86282
# 66/66 [==============================] - 5s 72ms/step - loss: 0.6210 - accuracy: 0.7242 - val_loss: 0.9434 - val_accuracy: 0.6154
# Epoch 46/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6487 - accuracy: 0.7242
# Epoch 46: val_loss did not improve from 0.86282
# 66/66 [==============================] - 6s 98ms/step - loss: 0.6487 - accuracy: 0.7242 - val_loss: 0.9794 - val_accuracy: 0.6154
# Epoch 47/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6311 - accuracy: 0.7545
# Epoch 47: val_loss did not improve from 0.86282
# 66/66 [==============================] - 5s 70ms/step - loss: 0.6311 - accuracy: 0.7545 - val_loss: 0.8969 - val_accuracy: 0.6308
# Epoch 48/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6086 - accuracy: 0.7455
# Epoch 48: val_loss did not improve from 0.86282
# 66/66 [==============================] - 6s 88ms/step - loss: 0.6086 - accuracy: 0.7455 - val_loss: 0.9027 - val_accuracy: 0.6462
# Epoch 49/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6130 - accuracy: 0.7485
# Epoch 49: val_loss did not improve from 0.86282
# 66/66 [==============================] - 6s 88ms/step - loss: 0.6130 - accuracy: 0.7485 - val_loss: 0.9088 - val_accuracy: 0.6462
# Epoch 50/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5416 - accuracy: 0.8061
# Epoch 50: val_loss did not improve from 0.86282
# 66/66 [==============================] - 6s 84ms/step - loss: 0.5416 - accuracy: 0.8061 - val_loss: 1.0277 - val_accuracy: 0.6308
# Epoch 51/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5481 - accuracy: 0.7606
# Epoch 51: val_loss did not improve from 0.86282
# 66/66 [==============================] - 5s 74ms/step - loss: 0.5481 - accuracy: 0.7606 - val_loss: 0.8805 - val_accuracy: 0.6154
# Epoch 52/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5365 - accuracy: 0.7909
# Epoch 52: val_loss did not improve from 0.86282
# 66/66 [==============================] - 6s 90ms/step - loss: 0.5365 - accuracy: 0.7909 - val_loss: 0.8967 - val_accuracy: 0.6154
# Epoch 53/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.7697
# Epoch 53: val_loss improved from 0.86282 to 0.84557, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 91ms/step - loss: 0.4939 - accuracy: 0.7697 - val_loss: 0.8456 - val_accuracy: 0.6769
# Epoch 54/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4922 - accuracy: 0.7909
# Epoch 54: val_loss did not improve from 0.84557
# 66/66 [==============================] - 5s 71ms/step - loss: 0.4922 - accuracy: 0.7909 - val_loss: 0.8649 - val_accuracy: 0.6769
# Epoch 55/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5242 - accuracy: 0.7788
# Epoch 55: val_loss did not improve from 0.84557
# 66/66 [==============================] - 6s 89ms/step - loss: 0.5242 - accuracy: 0.7788 - val_loss: 0.8541 - val_accuracy: 0.6462
# Epoch 56/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4851 - accuracy: 0.8152
# Epoch 56: val_loss improved from 0.84557 to 0.81339, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 90ms/step - loss: 0.4851 - accuracy: 0.8152 - val_loss: 0.8134 - val_accuracy: 0.6769
# Epoch 57/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5066 - accuracy: 0.7879
# Epoch 57: val_loss did not improve from 0.81339
# 66/66 [==============================] - 6s 91ms/step - loss: 0.5066 - accuracy: 0.7879 - val_loss: 0.9594 - val_accuracy: 0.6769
# Epoch 58/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4927 - accuracy: 0.8061
# Epoch 58: val_loss did not improve from 0.81339
# 66/66 [==============================] - 5s 72ms/step - loss: 0.4927 - accuracy: 0.8061 - val_loss: 0.8765 - val_accuracy: 0.6154
# Epoch 59/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5285 - accuracy: 0.7788
# Epoch 59: val_loss did not improve from 0.81339
# 66/66 [==============================] - 9s 134ms/step - loss: 0.5285 - accuracy: 0.7788 - val_loss: 0.9588 - val_accuracy: 0.6154
# Epoch 60/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.7970
# Epoch 60: val_loss did not improve from 0.81339
# 66/66 [==============================] - 6s 92ms/step - loss: 0.5000 - accuracy: 0.7970 - val_loss: 0.8342 - val_accuracy: 0.6615
# Epoch 61/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4843 - accuracy: 0.8061
# Epoch 61: val_loss did not improve from 0.81339
# 66/66 [==============================] - 7s 109ms/step - loss: 0.4843 - accuracy: 0.8061 - val_loss: 0.8662 - val_accuracy: 0.6769
# Epoch 62/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4798 - accuracy: 0.8182
# Epoch 62: val_loss did not improve from 0.81339
# 66/66 [==============================] - 6s 83ms/step - loss: 0.4798 - accuracy: 0.8182 - val_loss: 0.9098 - val_accuracy: 0.6308
# Epoch 63/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5044 - accuracy: 0.7909
# Epoch 63: val_loss did not improve from 0.81339
# 66/66 [==============================] - 6s 87ms/step - loss: 0.5044 - accuracy: 0.7909 - val_loss: 0.8908 - val_accuracy: 0.6615
# Epoch 64/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.7970
# Epoch 64: val_loss did not improve from 0.81339
# 66/66 [==============================] - 5s 77ms/step - loss: 0.5001 - accuracy: 0.7970 - val_loss: 0.8755 - val_accuracy: 0.6615
# Epoch 65/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4771 - accuracy: 0.8212
# Epoch 65: val_loss improved from 0.81339 to 0.70027, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 77ms/step - loss: 0.4771 - accuracy: 0.8212 - val_loss: 0.7003 - val_accuracy: 0.6923
# Epoch 66/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.8242
# Epoch 66: val_loss did not improve from 0.70027
# 66/66 [==============================] - 5s 73ms/step - loss: 0.4511 - accuracy: 0.8242 - val_loss: 0.7367 - val_accuracy: 0.7385
# Epoch 67/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4208 - accuracy: 0.8273
# Epoch 67: val_loss did not improve from 0.70027
# 66/66 [==============================] - 7s 105ms/step - loss: 0.4208 - accuracy: 0.8273 - val_loss: 0.8008 - val_accuracy: 0.7077
# Epoch 68/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4124 - accuracy: 0.8455
# Epoch 68: val_loss did not improve from 0.70027
# 66/66 [==============================] - 5s 70ms/step - loss: 0.4124 - accuracy: 0.8455 - val_loss: 0.7974 - val_accuracy: 0.7077
# Epoch 69/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4012 - accuracy: 0.8364
# Epoch 69: val_loss improved from 0.70027 to 0.62311, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 74ms/step - loss: 0.4012 - accuracy: 0.8364 - val_loss: 0.6231 - val_accuracy: 0.7385
# Epoch 70/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4095 - accuracy: 0.8394
# Epoch 70: val_loss did not improve from 0.62311
# 66/66 [==============================] - 7s 106ms/step - loss: 0.4095 - accuracy: 0.8394 - val_loss: 0.8395 - val_accuracy: 0.7077
# Epoch 71/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4239 - accuracy: 0.7970
# Epoch 71: val_loss did not improve from 0.62311
# 66/66 [==============================] - 5s 72ms/step - loss: 0.4239 - accuracy: 0.7970 - val_loss: 0.7704 - val_accuracy: 0.7385
# Epoch 72/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4768 - accuracy: 0.8121
# Epoch 72: val_loss did not improve from 0.62311
# 66/66 [==============================] - 5s 70ms/step - loss: 0.4768 - accuracy: 0.8121 - val_loss: 0.6697 - val_accuracy: 0.7385
# Epoch 73/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4047 - accuracy: 0.8364
# Epoch 73: val_loss did not improve from 0.62311
# 66/66 [==============================] - 7s 105ms/step - loss: 0.4047 - accuracy: 0.8364 - val_loss: 0.6912 - val_accuracy: 0.7231
# Epoch 74/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3669 - accuracy: 0.8576
# Epoch 74: val_loss did not improve from 0.62311
# 66/66 [==============================] - 5s 72ms/step - loss: 0.3669 - accuracy: 0.8576 - val_loss: 0.6715 - val_accuracy: 0.7231
# Epoch 75/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4410 - accuracy: 0.8121
# Epoch 75: val_loss did not improve from 0.62311
# 66/66 [==============================] - 6s 89ms/step - loss: 0.4410 - accuracy: 0.8121 - val_loss: 0.7260 - val_accuracy: 0.7231
# Epoch 76/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4054 - accuracy: 0.8303
# Epoch 76: val_loss did not improve from 0.62311
# 66/66 [==============================] - 6s 97ms/step - loss: 0.4054 - accuracy: 0.8303 - val_loss: 0.7045 - val_accuracy: 0.7231
# Epoch 77/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3939 - accuracy: 0.8273
# Epoch 77: val_loss improved from 0.62311 to 0.60012, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 71ms/step - loss: 0.3939 - accuracy: 0.8273 - val_loss: 0.6001 - val_accuracy: 0.7692
# Epoch 78/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8879
# Epoch 78: val_loss did not improve from 0.60012
# 66/66 [==============================] - 5s 77ms/step - loss: 0.3247 - accuracy: 0.8879 - val_loss: 0.7756 - val_accuracy: 0.8000
# Epoch 79/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4030 - accuracy: 0.8273
# Epoch 79: val_loss did not improve from 0.60012
# 66/66 [==============================] - 6s 98ms/step - loss: 0.4030 - accuracy: 0.8273 - val_loss: 0.6307 - val_accuracy: 0.7692
# Epoch 80/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4133 - accuracy: 0.8273
# Epoch 80: val_loss improved from 0.60012 to 0.57151, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 69ms/step - loss: 0.4133 - accuracy: 0.8273 - val_loss: 0.5715 - val_accuracy: 0.7538
# Epoch 81/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.3367 - accuracy: 0.8615
# Epoch 81: val_loss did not improve from 0.57151
# 66/66 [==============================] - 7s 103ms/step - loss: 0.3375 - accuracy: 0.8576 - val_loss: 0.6787 - val_accuracy: 0.7538
# Epoch 82/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4023 - accuracy: 0.8576
# Epoch 82: val_loss improved from 0.57151 to 0.53231, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 70ms/step - loss: 0.4023 - accuracy: 0.8576 - val_loss: 0.5323 - val_accuracy: 0.8308
# Epoch 83/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3394 - accuracy: 0.8636
# Epoch 83: val_loss improved from 0.53231 to 0.52258, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 100ms/step - loss: 0.3394 - accuracy: 0.8636 - val_loss: 0.5226 - val_accuracy: 0.7692
# Epoch 84/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3594 - accuracy: 0.8303
# Epoch 84: val_loss improved from 0.52258 to 0.49560, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 75ms/step - loss: 0.3594 - accuracy: 0.8303 - val_loss: 0.4956 - val_accuracy: 0.8000
# Epoch 85/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.8727
# Epoch 85: val_loss improved from 0.49560 to 0.47281, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 94ms/step - loss: 0.3726 - accuracy: 0.8727 - val_loss: 0.4728 - val_accuracy: 0.8308
# Epoch 86/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3533 - accuracy: 0.8667
# Epoch 86: val_loss did not improve from 0.47281
# 66/66 [==============================] - 7s 105ms/step - loss: 0.3533 - accuracy: 0.8667 - val_loss: 0.6043 - val_accuracy: 0.7231
# Epoch 87/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3609 - accuracy: 0.8515
# Epoch 87: val_loss did not improve from 0.47281
# 66/66 [==============================] - 6s 88ms/step - loss: 0.3609 - accuracy: 0.8515 - val_loss: 0.4872 - val_accuracy: 0.8462
# Epoch 88/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.8394
# Epoch 88: val_loss did not improve from 0.47281
# 66/66 [==============================] - 6s 83ms/step - loss: 0.3752 - accuracy: 0.8394 - val_loss: 0.6206 - val_accuracy: 0.6923
# Epoch 89/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.8970
# Epoch 89: val_loss did not improve from 0.47281
# 66/66 [==============================] - 6s 86ms/step - loss: 0.3003 - accuracy: 0.8970 - val_loss: 0.5920 - val_accuracy: 0.7846
# Epoch 90/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3833 - accuracy: 0.8667
# Epoch 90: val_loss did not improve from 0.47281
# 66/66 [==============================] - 5s 71ms/step - loss: 0.3833 - accuracy: 0.8667 - val_loss: 0.4804 - val_accuracy: 0.8462
# Epoch 91/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3234 - accuracy: 0.8667
# Epoch 91: val_loss improved from 0.47281 to 0.43103, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 88ms/step - loss: 0.3234 - accuracy: 0.8667 - val_loss: 0.4310 - val_accuracy: 0.8462
# Epoch 92/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3065 - accuracy: 0.8758
# Epoch 92: val_loss did not improve from 0.43103
# 66/66 [==============================] - 6s 85ms/step - loss: 0.3065 - accuracy: 0.8758 - val_loss: 0.5873 - val_accuracy: 0.7231
# Epoch 93/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.8818
# Epoch 93: val_loss did not improve from 0.43103
# 66/66 [==============================] - 5s 70ms/step - loss: 0.3159 - accuracy: 0.8818 - val_loss: 0.6042 - val_accuracy: 0.7692
# Epoch 94/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3278 - accuracy: 0.8879
# Epoch 94: val_loss did not improve from 0.43103
# 66/66 [==============================] - 6s 86ms/step - loss: 0.3278 - accuracy: 0.8879 - val_loss: 0.6168 - val_accuracy: 0.6769
# Epoch 95/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3778 - accuracy: 0.8515
# Epoch 95: val_loss did not improve from 0.43103
# 66/66 [==============================] - 6s 88ms/step - loss: 0.3778 - accuracy: 0.8515 - val_loss: 0.4888 - val_accuracy: 0.7077
# Epoch 96/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3285 - accuracy: 0.8727
# Epoch 96: val_loss did not improve from 0.43103
# 66/66 [==============================] - 5s 69ms/step - loss: 0.3285 - accuracy: 0.8727 - val_loss: 0.4998 - val_accuracy: 0.8462
# Epoch 97/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3197 - accuracy: 0.8758
# Epoch 97: val_loss did not improve from 0.43103
# 66/66 [==============================] - 6s 86ms/step - loss: 0.3197 - accuracy: 0.8758 - val_loss: 0.5753 - val_accuracy: 0.7385
# Epoch 98/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.9061
# Epoch 98: val_loss improved from 0.43103 to 0.40320, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 88ms/step - loss: 0.3099 - accuracy: 0.9061 - val_loss: 0.4032 - val_accuracy: 0.8923
# Epoch 99/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3553 - accuracy: 0.8576
# Epoch 99: val_loss did not improve from 0.40320
# 66/66 [==============================] - 5s 80ms/step - loss: 0.3553 - accuracy: 0.8576 - val_loss: 0.4495 - val_accuracy: 0.7692
# Epoch 100/100
# 66/66 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.9061
# Epoch 100: val_loss improved from 0.40320 to 0.39798, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 95ms/step - loss: 0.2605 - accuracy: 0.9061 - val_loss: 0.3980 - val_accuracy: 0.8923

# %%
# 결과 그래프를 그려보아요!

fig = plt.figure()

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(history.history['loss'], color='r')
ax1.plot(history.history['val_loss'], color='b')

ax2.plot(history.history['accuracy'], color='r')
ax2.plot(history.history['val_accuracy'], color='b')

plt.tight_layout()
plt.show()

# %% [markdown]
# - 학습 데이터가 부족할 때, 데이터의 양을 늘리기 위해 증식을 사용
# - 이는 overfitting을 줄이는 것
# - 이 모델 자체의 accuracy를 높이는 것은 아님

# %% [markdown]
# **이를 해결하기 위해 바로 아래의 Pretrained Network를 이용해야 한다**

# %% [markdown]
# # 여기까지 모델로 Test 진행

# %%
# 테스트에 필요한 module import
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

# %%
# 저장된 모델 파일의 경로
saved_model_path = '/content/infantface_cnn_model.h5'

# 테스트할 이미지 경로 설정
test_image_path = '/content/drive/MyDrive/KOSA3/project/data/test_neg2.png'

# 모델 로드
loaded_model = load_model(saved_model_path)

# 이미지 불러오기 및 전처리
img = image.load_img(test_image_path, target_size=(150, 150))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
# 모델 예측
predictions = loaded_model.predict(img_array)

# 예측 결과 해석 및 출력
class_indices = np.argmax(predictions, axis=1)

# 각 클래스의 인덱스에 따른 레이블 설정 (positive, neutral, negative)
class_labels = ['positive', 'neutral', 'negative']
predicted_label = class_labels[class_indices[0]]

print(f"Predicted Class: {predicted_label}")
# Out:
# 1/1 [==============================] - 0s 73ms/step
# Predicted Class: negative
