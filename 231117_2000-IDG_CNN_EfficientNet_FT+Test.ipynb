# %% [markdown]
# 수정사항
# - augmentation 조정

# %%
# 시작 전에 GPU로 바꿔주기

# %% [markdown]
# # CNN 모델 만들고, ImageDataGenerator을 이용해서 학습 진행하기

# %%
# 필요한 module import
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Google Drive 접근 = 구글 마운트하기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## ImageDataGenerator 만들기 (rescale만 이용 / 다른 augmentation 제외)

# %%
# 이미지들이 있는 train, validation 폴더 가져오기
# 이 이미지들은 본인의 Local 파일에 각각 저장되어 있어야한다
# FinalProject에 있는 infant라는 폴더를 본인의 드라이브에 넣기!

train_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/train'
validation_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/valid'

# %%
# ImageDataGenerator 객체 생성

train_datagen = ImageDataGenerator(rescale=1/255) # 0 or 1의 값이 나올 수 있도록 255로 나누어 준다
validation_datagen=ImageDataGenerator(rescale=1/255)


# ImageDataGenerator 객체 세부 설정
# 넌 이렇게 동작해야해! 라고 세부 세팅을 해준다

train_generator = train_datagen.flow_from_directory( # train_datagen.flow_from_directory() 특정 폴더로부터 generator을 뽑아내는 객체를 하나 만든다
    train_dir, # target directory
    classes=['positive', 'neutral', 'negative'], # train 안에 있는 폴더를 내가 원하는 순서대로 준다 (positive -> neutral -> negative)
                                                 # label(target) 지정, list의 순서대로 지정하기!
                                                 # 만약 생략되면 폴더 순서는 오름차순으로 지정된다.
    target_size=(150, 150), #image resize
    batch_size=5, # 한번에 20개의 이미지를 가져온다
                   # label에 상관없이 이미지를 가져온다
    class_mode='categorical' # 다중분류 : categorical, 이진분류 : binary
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    classes=['positive', 'neutral', 'negative'],
    target_size=(150, 150), # 평가 데이터이기 떄문에 size를 똑같이 가져와야 한다
    batch_size=5,
    class_mode='categorical'
)

# Found 330 images belonging to 3 classes.
# Found 65 images belonging to 3 classes.
# Out:
# Found 330 images belonging to 3 classes.
# Found 65 images belonging to 3 classes.

# %% [markdown]
# ## CNN Model 구현

# %%
# 필터의 개수는 앞쪽에서 뒤쪽으로 갈 수록 많아지는 것이 좋다
# 필터의 크기(kernel_size)는 3x3 을 보통 쓴다

model = Sequential()

model.add(Conv2D(filters=32,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu',
                 input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))  # 여기서는 input_shape을 빼주어야한다
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=256,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# model.summary() # 중간에 확인해주고 넘어가기

model.add(Flatten())
model.add(Dropout(rate=0.5))
model.add(Dense(units=256,
                activation='relu'))
model.add(Dense(units=3,
                activation='softmax'))

model.summary()


# Total params: 3600707 (13.74 MB)
# Trainable params: 3600707 (13.74 MB) -> 학습이 가능한, 값이 바뀌는 파라미터
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 7, 7, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dropout (Dropout)           (None, 12544)             0
#
#  dense (Dense)               (None, 256)               3211520
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 3600707 (13.74 MB)
# Trainable params: 3600707 (13.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# model 학습 설정


model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


# model checkpoint 확인
model_cp = ModelCheckpoint(filepath='infantface_checkpoint.ckpt', # 임시로 제공 받은 runtime disk에 파일이 만들어진다. 계산된 가중치를 저장해놓자
                           save_weights_only=True,
                           save_best_only=True,
                           monitor='val_loss',
                           verbose=1)

# model earlystopping 확인(조기 종료는 언제할까요?)
model_es = EarlyStopping(monitor='val_loss',
                         patience=5,
                         verbose=1,
                         restore_best_weights=True)


history = model.fit(train_generator,
                    steps_per_epoch=66,  # 1 epoch 당 몇 번 수행할지 정해주어야 한다. 이것도 직접 계산 330/5 = 66
                    epochs=100,
                    verbose=1,
                    #validation_split=0.3 이라고 썼었는데, 이제 validation_data가 따로 있기 때문에
                    validation_data=validation_generator,
                    validation_steps=13, # 계산해서 넣어주어야 한다
                                         # 즉, 65/5 = 13
                    callbacks=[model_cp, model_es])


model.save('./infantface_cnn_model.h5') # 학습이 끝나면, 우리 모델에 대해서 한 번에 딱 저장
# 저장하는 방법 2가지
# 1. checkpoint와 callback을 이용해서 epoch마다 저장해준다
# 2. 모델에 있어서 한 번에 저장


# 위 처럼 만들고 model 학습 진행 (shift+enter)
# Out:
# Epoch 1/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0904 - accuracy: 0.3939
# Epoch 1: val_loss improved from inf to 1.07905, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 68s 841ms/step - loss: 1.0904 - accuracy: 0.3939 - val_loss: 1.0791 - val_accuracy: 0.4000
# Epoch 2/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0883 - accuracy: 0.3818
# Epoch 2: val_loss improved from 1.07905 to 1.07093, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 4s 57ms/step - loss: 1.0883 - accuracy: 0.3818 - val_loss: 1.0709 - val_accuracy: 0.4000
# Epoch 3/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0737 - accuracy: 0.4758
# Epoch 3: val_loss improved from 1.07093 to 1.02697, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 4s 61ms/step - loss: 1.0737 - accuracy: 0.4758 - val_loss: 1.0270 - val_accuracy: 0.5231
# Epoch 4/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9479 - accuracy: 0.5394
# Epoch 4: val_loss improved from 1.02697 to 0.90718, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 48ms/step - loss: 0.9479 - accuracy: 0.5394 - val_loss: 0.9072 - val_accuracy: 0.6154
# Epoch 5/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.7964 - accuracy: 0.6462
# Epoch 5: val_loss improved from 0.90718 to 0.86499, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 46ms/step - loss: 0.8023 - accuracy: 0.6394 - val_loss: 0.8650 - val_accuracy: 0.6308
# Epoch 6/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.7439 - accuracy: 0.6923
# Epoch 6: val_loss did not improve from 0.86499
# 66/66 [==============================] - 4s 54ms/step - loss: 0.7538 - accuracy: 0.6879 - val_loss: 0.8691 - val_accuracy: 0.5846
# Epoch 7/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6735 - accuracy: 0.7212
# Epoch 7: val_loss improved from 0.86499 to 0.82992, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 51ms/step - loss: 0.6735 - accuracy: 0.7212 - val_loss: 0.8299 - val_accuracy: 0.6615
# Epoch 8/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.5694 - accuracy: 0.7846
# Epoch 8: val_loss did not improve from 0.82992
# 66/66 [==============================] - 3s 45ms/step - loss: 0.5649 - accuracy: 0.7879 - val_loss: 0.8580 - val_accuracy: 0.6308
# Epoch 9/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.4840 - accuracy: 0.8215
# Epoch 9: val_loss improved from 0.82992 to 0.79919, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 49ms/step - loss: 0.4801 - accuracy: 0.8242 - val_loss: 0.7992 - val_accuracy: 0.6923
# Epoch 10/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4717 - accuracy: 0.7970
# Epoch 10: val_loss did not improve from 0.79919
# 66/66 [==============================] - 4s 59ms/step - loss: 0.4717 - accuracy: 0.7970 - val_loss: 0.8441 - val_accuracy: 0.6615
# Epoch 11/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3962 - accuracy: 0.8667
# Epoch 11: val_loss did not improve from 0.79919
# 66/66 [==============================] - 3s 48ms/step - loss: 0.3962 - accuracy: 0.8667 - val_loss: 0.8136 - val_accuracy: 0.6769
# Epoch 12/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.3371 - accuracy: 0.8831
# Epoch 12: val_loss improved from 0.79919 to 0.70051, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 49ms/step - loss: 0.3352 - accuracy: 0.8848 - val_loss: 0.7005 - val_accuracy: 0.7231
# Epoch 13/100
# 66/66 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.9061
# Epoch 13: val_loss improved from 0.70051 to 0.67530, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 4s 61ms/step - loss: 0.2823 - accuracy: 0.9061 - val_loss: 0.6753 - val_accuracy: 0.7538
# Epoch 14/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.2513 - accuracy: 0.9077
# Epoch 14: val_loss did not improve from 0.67530
# 66/66 [==============================] - 4s 57ms/step - loss: 0.2490 - accuracy: 0.9091 - val_loss: 0.7267 - val_accuracy: 0.7846
# Epoch 15/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.2356 - accuracy: 0.9292
# Epoch 15: val_loss improved from 0.67530 to 0.57545, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 51ms/step - loss: 0.2340 - accuracy: 0.9303 - val_loss: 0.5754 - val_accuracy: 0.8000
# Epoch 16/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.1685 - accuracy: 0.9446
# Epoch 16: val_loss improved from 0.57545 to 0.55727, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 50ms/step - loss: 0.1675 - accuracy: 0.9455 - val_loss: 0.5573 - val_accuracy: 0.8308
# Epoch 17/100
# 66/66 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9636
# Epoch 17: val_loss did not improve from 0.55727
# 66/66 [==============================] - 4s 59ms/step - loss: 0.1611 - accuracy: 0.9636 - val_loss: 0.5703 - val_accuracy: 0.7692
# Epoch 18/100
# 66/66 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9424
# Epoch 18: val_loss did not improve from 0.55727
# 66/66 [==============================] - 4s 53ms/step - loss: 0.1658 - accuracy: 0.9424 - val_loss: 0.5667 - val_accuracy: 0.7846
# Epoch 19/100
# 66/66 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.9636
# Epoch 19: val_loss improved from 0.55727 to 0.49839, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 47ms/step - loss: 0.1214 - accuracy: 0.9636 - val_loss: 0.4984 - val_accuracy: 0.8154
# Epoch 20/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.1217 - accuracy: 0.9538
# Epoch 20: val_loss did not improve from 0.49839
# 66/66 [==============================] - 4s 58ms/step - loss: 0.1201 - accuracy: 0.9545 - val_loss: 0.5269 - val_accuracy: 0.7846
# Epoch 21/100
# 66/66 [==============================] - ETA: 0s - loss: 0.1628 - accuracy: 0.9515
# Epoch 21: val_loss improved from 0.49839 to 0.39592, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 4s 53ms/step - loss: 0.1628 - accuracy: 0.9515 - val_loss: 0.3959 - val_accuracy: 0.9077
# Epoch 22/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0710 - accuracy: 0.9815
# Epoch 22: val_loss did not improve from 0.39592
# 66/66 [==============================] - 3s 45ms/step - loss: 0.0700 - accuracy: 0.9818 - val_loss: 0.4525 - val_accuracy: 0.8769
# Epoch 23/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.9723
# Epoch 23: val_loss improved from 0.39592 to 0.36706, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 3s 49ms/step - loss: 0.0950 - accuracy: 0.9727 - val_loss: 0.3671 - val_accuracy: 0.8923
# Epoch 24/100
# 66/66 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9818
# Epoch 24: val_loss did not improve from 0.36706
# 66/66 [==============================] - 3s 49ms/step - loss: 0.0551 - accuracy: 0.9818 - val_loss: 0.4422 - val_accuracy: 0.8769
# Epoch 25/100
# 66/66 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9879
# Epoch 25: val_loss did not improve from 0.36706
# 66/66 [==============================] - 4s 62ms/step - loss: 0.0509 - accuracy: 0.9879 - val_loss: 0.5691 - val_accuracy: 0.8615
# Epoch 26/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9846
# Epoch 26: val_loss did not improve from 0.36706
# 66/66 [==============================] - 3s 53ms/step - loss: 0.0421 - accuracy: 0.9848 - val_loss: 0.3742 - val_accuracy: 0.9231
# Epoch 27/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9969
# Epoch 27: val_loss did not improve from 0.36706
# 66/66 [==============================] - 3s 45ms/step - loss: 0.0231 - accuracy: 0.9970 - val_loss: 0.5439 - val_accuracy: 0.8462
# Epoch 28/100
# 66/66 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9970
# Epoch 28: val_loss did not improve from 0.36706
# Restoring model weights from the end of the best epoch: 23.
# 66/66 [==============================] - 3s 45ms/step - loss: 0.0360 - accuracy: 0.9970 - val_loss: 0.5185 - val_accuracy: 0.8769
# Epoch 28: early stopping
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# 마지막 결과값
# 66/66 [==============================] - 3s 45ms/step - loss: 0.0360 - accuracy: 0.9970 - val_loss: 0.5185 - val_accuracy: 0.8769
# Epoch 28: early stopping

# 기준을 어떻게 세워야 하는가?
# 1. loss, val_loss
# 기준 : 손실은 모델이 실제 값과 예측 값 간의 차이를 나타내므로, "낮을수록 좋다"
# 해석 : 훈련 손실과 검증 손실이 둘 다 감소하는 것은, 모델이 데이터에 잘 적함되고 있다는 것을 나타낸다.
#       그러나, 두 손실이 크게 차이나는 경우에는 과적합이 발생할 가능성이 있으므로 주의가 필요
# 2. accuracy, val_accuracy
# 기준 : 모델이 올바르게 분류한 샘플의 비율을 나타내므로, "높을수록 좋다"
# 해석 : 훈련 정확도와 검증 정확도가 둘 다 증가하는 것은 모델이 데이터를 잘 이해하고 일반화되고 있다는 것을 나타냅니다.
#       과적합이 발생하지 않도록 주의해야 합니다.

# %%
# 결과 그래프를 그려보아요!
# 이때, 그래프를 해석할 줄 알아야 한다.
# 기준 : loss(훈련 손실)과 val_loss(검증 손실) 차이가 크지 않고,
#       accarcy(훈련 정확도) val_accuracy(검증 정확도)가 유사한지 확인해봐야한다.
# 해석 : 이러한 관계가 유지되면 모델이 새로운 데이터에 대해 일반화할 수 있음을 나타내며, 과적합이 발생하지 않았음을 이야기함.
# 만약, val_loss의 선인 파란선이 중간에 상승하는 모습을 보인다면 = Overfitting --> 차이가 생기기 시작하기 때문!

import matplotlib.pyplot as plt
fig = plt.figure()

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(history.history['loss'], color='r')
ax1.plot(history.history['val_loss'], color='b')

ax2.plot(history.history['accuracy'], color='r')
ax2.plot(history.history['val_accuracy'], color='b')

plt.tight_layout()
plt.show()

# %%
# Early Stopping 및 Model Checkpoint 콜백 활용
# 어떻게?
# Early Stopping과 Model Checkpoint 콜백을 사용하여 검증 손실이 더 이상 감소하지 않거나 증가하기 시작할 때 학습을 조기 종료하고 최적의 모델을 저장합니다.
# 해석
# 이는 모델이 더 이상 개선되지 않고 있거나 과적합이 시작될 때 학습을 중단하여 일반화된 모델을 얻을 수 있도록 도와줍니다.

# %% [markdown]
# **OverFitting 줄이는 방법**
#
#
# 1. Feature의 개수 줄이기
# 2. 규제(L1, L2)
# 3. Dropout
#
# 가장 중요한 방법은!
# 4. Data가 많으면 된다
#    Image를 증식(Augmenation)을 이용해서 학습하면 되겠다!
#
#    but, 증식 데이터는 '코드'를 구현해야 한다.
#
#    이 코드는 ImageDataGenerator가 제공한다

# %% [markdown]
# ## ImageDataGenerator을 이용해 overfitting 해결하기 (rescale을 비롯한 다른 augmentation 활용)

# %% [markdown]
# ### 이미지 1장을 이용해 증식 사용해보기

# %%
# 필요한 module import
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
# 원하는 증식 정도를 모두 적어주기
datagen = ImageDataGenerator(rotation_range=20, # 회전 각도를 주어서 이미지를 변형
                             width_shift_range=0.1, # 10% 정도의 비율의 범위 내에서만 이동해라
                             height_shift_range=0.1,
                             shear_range=0.1,
                             zoom_range=0.2,
                             horizontal_flip=True,
                             fill_mode='nearest' # 이미지가 생길 수 있는 빈 공간이 생기는데 그 빈공간을 'nearest'로 근처에 있는 픽셀의 값으로 채워라)
                             )

# %%
# 원하는 이미지 1장을 증식해보기!
img = image.load_img('/content/drive/MyDrive/KOSA3/project/data/infantface/train/positive/Pos1.bmp',
                     target_size=(150,150))

# 원래는 numpy array가 나와야 함
# 확인
print(type(img)) # <class 'PIL.Image.Image'> --> numpy array가 아니기 때문에 이로 바꾸어주어야함

# numpy array로 바꿔줌
x = image.img_to_array(img)
print(type(x), x.shape)  # <class 'numpy.ndarray'> (150, 150, 3)
# 현재 이미지가 1장이다. 이 이미지에 대해서 ImageDataGenerator를 이용해서
# Augmentation(증식)된 이미지를 뽑을것이다.

# 그런데 ImageDataGenerator은 여러장의 이미지를 추출하는 거라서
# 기본적으로 4차원이 필요하다 (하지만, 현재 가지고 있는 것은 3차원이다)
x = x.reshape((1,) + x.shape) # x라는 4차원 데이터를 준비
print(x.shape)  # (1, 150, 150, 3)



# 증식된 이미지 20장을 그려보자
# 이미지의 개수를 확 늘려서(데이터의 개수를 늘려서)
# overfitting을 줄이자!

fig = plt.figure()
axs = []

for i in range(20):
    axs.append(fig.add_subplot(4,5,i+1))

idx = 0
for batch in datagen.flow(x, batch_size=1):
    axs[idx].imshow(image.array_to_img(batch[0]))
    idx += 1
    if idx % 20 == 0:
        break;
# Out:
# <class 'PIL.Image.Image'>
# <class 'numpy.ndarray'> (150, 150, 3)
# (1, 150, 150, 3)

# %% [markdown]
# ### 증식을 이용해 학습 진행해보기

# %%
# 필요한 module import
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# ImageDataGenerator 생성

#  dir 불러오기
train_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/train'
validation_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/valid'

# ImageDataGenerator를 생성(객체 생성)
train_datagen = ImageDataGenerator(rescale=1/255,
                                   rotation_range=20,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   shear_range=0.1,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   fill_mode='nearest')
validation_datagen = ImageDataGenerator(rescale=1/255)

# ImageDataGenerator 객체 세부 설정
# 넌 이렇게 동작해야해! 라고 세부 세팅을 해준다

train_generator = train_datagen.flow_from_directory(
    train_dir,
    classes=['positive', 'neutral', 'negative'],
    target_size=(150, 150),
    batch_size=5,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    classes=['positive', 'neutral', 'negative'],
    target_size=(150, 150),
    batch_size=5,
    class_mode='categorical'
)
# Out:
# Found 330 images belonging to 3 classes.
# Found 65 images belonging to 3 classes.

# %%
# Model 구현
# 위에서 만든 Model과 똑같음 (copy&paste)

model = Sequential()

model.add(Conv2D(filters=32,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu',
                 input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=256,
                 kernel_size=(3,3),
                 strides=(1,1),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dropout(rate=0.5))
model.add(Dense(units=256,
                activation='relu'))
model.add(Dense(units=3,
                activation='softmax'))

# %% [markdown]
# 수정한 것
# 1.  EarlyStopping의 patience 수를 높임
#     66/66 [==============================] - 5s 69ms/step - loss: 0.8461 - accuracy: 0.5939 - val_loss: 1.0182 - val_accuracy: 0.5846
# Epoch 6: early stopping
# -> 학습결과가 좋지 않아서
# 2. earlystopping을 없앰

# %%
# Model 학습 설정 및 진행

# model 학습 설정
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


# model checkpoint 확인
model_cp = ModelCheckpoint(filepath='infantface_checkpoint.ckpt',
                           save_weights_only=True,
                           save_best_only=True,
                           monitor='val_loss',
                           verbose=1)

# model earlystopping 확인(조기 종료는 언제할까요?)
model_es = EarlyStopping(monitor='val_loss',
                         patience=5,
                         verbose=1,
                         restore_best_weights=True)



history = model.fit(train_generator,
                    steps_per_epoch=66,
                    epochs=100,
                    verbose=1,
                    validation_data=validation_generator,
                    validation_steps=13,
                    callbacks=[model_cp])


model.save('./infantface_IDG_cnn_model.h5')
# Out:
# Epoch 1/100
# 66/66 [==============================] - ETA: 0s - loss: 1.1020 - accuracy: 0.3727
# Epoch 1: val_loss improved from inf to 1.08070, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 218s 3s/step - loss: 1.1020 - accuracy: 0.3727 - val_loss: 1.0807 - val_accuracy: 0.4000
# Epoch 2/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0913 - accuracy: 0.3879
# Epoch 2: val_loss improved from 1.08070 to 1.07874, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 82ms/step - loss: 1.0913 - accuracy: 0.3879 - val_loss: 1.0787 - val_accuracy: 0.4000
# Epoch 3/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0899 - accuracy: 0.3848
# Epoch 3: val_loss improved from 1.07874 to 1.07662, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 109ms/step - loss: 1.0899 - accuracy: 0.3848 - val_loss: 1.0766 - val_accuracy: 0.4000
# Epoch 4/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0879 - accuracy: 0.3879
# Epoch 4: val_loss did not improve from 1.07662
# 66/66 [==============================] - 7s 109ms/step - loss: 1.0879 - accuracy: 0.3879 - val_loss: 1.0776 - val_accuracy: 0.4000
# Epoch 5/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0854 - accuracy: 0.3818
# Epoch 5: val_loss did not improve from 1.07662
# 66/66 [==============================] - 8s 121ms/step - loss: 1.0854 - accuracy: 0.3818 - val_loss: 1.0775 - val_accuracy: 0.4000
# Epoch 6/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0863 - accuracy: 0.4030
# Epoch 6: val_loss improved from 1.07662 to 1.06488, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 77ms/step - loss: 1.0863 - accuracy: 0.4030 - val_loss: 1.0649 - val_accuracy: 0.4154
# Epoch 7/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0782 - accuracy: 0.3848
# Epoch 7: val_loss improved from 1.06488 to 1.03627, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 100ms/step - loss: 1.0782 - accuracy: 0.3848 - val_loss: 1.0363 - val_accuracy: 0.5538
# Epoch 8/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0604 - accuracy: 0.4636
# Epoch 8: val_loss improved from 1.03627 to 0.99131, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 89ms/step - loss: 1.0604 - accuracy: 0.4636 - val_loss: 0.9913 - val_accuracy: 0.5077
# Epoch 9/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0603 - accuracy: 0.4333
# Epoch 9: val_loss did not improve from 0.99131
# 66/66 [==============================] - 5s 74ms/step - loss: 1.0603 - accuracy: 0.4333 - val_loss: 1.0026 - val_accuracy: 0.4615
# Epoch 10/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0359 - accuracy: 0.4303
# Epoch 10: val_loss improved from 0.99131 to 0.94856, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 112ms/step - loss: 1.0359 - accuracy: 0.4303 - val_loss: 0.9486 - val_accuracy: 0.5692
# Epoch 11/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0259 - accuracy: 0.4909
# Epoch 11: val_loss did not improve from 0.94856
# 66/66 [==============================] - 5s 77ms/step - loss: 1.0259 - accuracy: 0.4909 - val_loss: 1.0205 - val_accuracy: 0.4923
# Epoch 12/100
# 66/66 [==============================] - ETA: 0s - loss: 1.0327 - accuracy: 0.4273
# Epoch 12: val_loss did not improve from 0.94856
# 66/66 [==============================] - 7s 111ms/step - loss: 1.0327 - accuracy: 0.4273 - val_loss: 0.9843 - val_accuracy: 0.5231
# Epoch 13/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9965 - accuracy: 0.5242
# Epoch 13: val_loss did not improve from 0.94856
# 66/66 [==============================] - 5s 75ms/step - loss: 0.9965 - accuracy: 0.5242 - val_loss: 0.9553 - val_accuracy: 0.5077
# Epoch 14/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9893 - accuracy: 0.5121
# Epoch 14: val_loss did not improve from 0.94856
# 66/66 [==============================] - 5s 76ms/step - loss: 0.9893 - accuracy: 0.5121 - val_loss: 0.9487 - val_accuracy: 0.5846
# Epoch 15/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9489 - accuracy: 0.5333
# Epoch 15: val_loss did not improve from 0.94856
# 66/66 [==============================] - 7s 112ms/step - loss: 0.9489 - accuracy: 0.5333 - val_loss: 0.9956 - val_accuracy: 0.5846
# Epoch 16/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9514 - accuracy: 0.5242
# Epoch 16: val_loss did not improve from 0.94856
# 66/66 [==============================] - 5s 74ms/step - loss: 0.9514 - accuracy: 0.5242 - val_loss: 0.9736 - val_accuracy: 0.6154
# Epoch 17/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9663 - accuracy: 0.5273
# Epoch 17: val_loss improved from 0.94856 to 0.92125, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 111ms/step - loss: 0.9663 - accuracy: 0.5273 - val_loss: 0.9212 - val_accuracy: 0.6154
# Epoch 18/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9381 - accuracy: 0.5061
# Epoch 18: val_loss did not improve from 0.92125
# 66/66 [==============================] - 5s 76ms/step - loss: 0.9381 - accuracy: 0.5061 - val_loss: 0.9568 - val_accuracy: 0.6000
# Epoch 19/100
# 66/66 [==============================] - ETA: 0s - loss: 0.9011 - accuracy: 0.5606
# Epoch 19: val_loss did not improve from 0.92125
# 66/66 [==============================] - 7s 103ms/step - loss: 0.9011 - accuracy: 0.5606 - val_loss: 1.0042 - val_accuracy: 0.6154
# Epoch 20/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8917 - accuracy: 0.5485
# Epoch 20: val_loss did not improve from 0.92125
# 66/66 [==============================] - 5s 73ms/step - loss: 0.8917 - accuracy: 0.5485 - val_loss: 1.0454 - val_accuracy: 0.6308
# Epoch 21/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8809 - accuracy: 0.5909
# Epoch 21: val_loss did not improve from 0.92125
# 66/66 [==============================] - 7s 103ms/step - loss: 0.8809 - accuracy: 0.5909 - val_loss: 1.0070 - val_accuracy: 0.5846
# Epoch 22/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8481 - accuracy: 0.6364
# Epoch 22: val_loss did not improve from 0.92125
# 66/66 [==============================] - 6s 85ms/step - loss: 0.8481 - accuracy: 0.6364 - val_loss: 0.9301 - val_accuracy: 0.5692
# Epoch 23/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8731 - accuracy: 0.5788
# Epoch 23: val_loss did not improve from 0.92125
# 66/66 [==============================] - 6s 98ms/step - loss: 0.8731 - accuracy: 0.5788 - val_loss: 0.9470 - val_accuracy: 0.5538
# Epoch 24/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8594 - accuracy: 0.5606
# Epoch 24: val_loss did not improve from 0.92125
# 66/66 [==============================] - 6s 88ms/step - loss: 0.8594 - accuracy: 0.5606 - val_loss: 0.9424 - val_accuracy: 0.6462
# Epoch 25/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8504 - accuracy: 0.6061
# Epoch 25: val_loss did not improve from 0.92125
# 66/66 [==============================] - 5s 73ms/step - loss: 0.8504 - accuracy: 0.6061 - val_loss: 0.9231 - val_accuracy: 0.6615
# Epoch 26/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8650 - accuracy: 0.5848
# Epoch 26: val_loss did not improve from 0.92125
# 66/66 [==============================] - 7s 110ms/step - loss: 0.8650 - accuracy: 0.5848 - val_loss: 1.1206 - val_accuracy: 0.5231
# Epoch 27/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8293 - accuracy: 0.6212
# Epoch 27: val_loss improved from 0.92125 to 0.91555, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 78ms/step - loss: 0.8293 - accuracy: 0.6212 - val_loss: 0.9156 - val_accuracy: 0.6154
# Epoch 28/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8444 - accuracy: 0.6212
# Epoch 28: val_loss improved from 0.91555 to 0.90631, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 98ms/step - loss: 0.8444 - accuracy: 0.6212 - val_loss: 0.9063 - val_accuracy: 0.5846
# Epoch 29/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8039 - accuracy: 0.6121
# Epoch 29: val_loss did not improve from 0.90631
# 66/66 [==============================] - 6s 90ms/step - loss: 0.8039 - accuracy: 0.6121 - val_loss: 0.9326 - val_accuracy: 0.6000
# Epoch 30/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8463 - accuracy: 0.6091
# Epoch 30: val_loss did not improve from 0.90631
# 66/66 [==============================] - 5s 75ms/step - loss: 0.8463 - accuracy: 0.6091 - val_loss: 0.9161 - val_accuracy: 0.5538
# Epoch 31/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7502 - accuracy: 0.6667
# Epoch 31: val_loss did not improve from 0.90631
# 66/66 [==============================] - 7s 108ms/step - loss: 0.7502 - accuracy: 0.6667 - val_loss: 0.9836 - val_accuracy: 0.5692
# Epoch 32/100
# 66/66 [==============================] - ETA: 0s - loss: 0.8005 - accuracy: 0.6424
# Epoch 32: val_loss improved from 0.90631 to 0.89905, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 75ms/step - loss: 0.8005 - accuracy: 0.6424 - val_loss: 0.8990 - val_accuracy: 0.6308
# Epoch 33/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7811 - accuracy: 0.6424
# Epoch 33: val_loss did not improve from 0.89905
# 66/66 [==============================] - 7s 103ms/step - loss: 0.7811 - accuracy: 0.6424 - val_loss: 0.9569 - val_accuracy: 0.5385
# Epoch 34/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7573 - accuracy: 0.6697
# Epoch 34: val_loss did not improve from 0.89905
# 66/66 [==============================] - 6s 83ms/step - loss: 0.7573 - accuracy: 0.6697 - val_loss: 0.9880 - val_accuracy: 0.5538
# Epoch 35/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7071 - accuracy: 0.7000
# Epoch 35: val_loss did not improve from 0.89905
# 66/66 [==============================] - 5s 75ms/step - loss: 0.7071 - accuracy: 0.7000 - val_loss: 0.9770 - val_accuracy: 0.5538
# Epoch 36/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7254 - accuracy: 0.6697
# Epoch 36: val_loss did not improve from 0.89905
# 66/66 [==============================] - 7s 102ms/step - loss: 0.7254 - accuracy: 0.6697 - val_loss: 0.9364 - val_accuracy: 0.5846
# Epoch 37/100
# 66/66 [==============================] - ETA: 0s - loss: 0.7645 - accuracy: 0.6515
# Epoch 37: val_loss did not improve from 0.89905
# 66/66 [==============================] - 5s 73ms/step - loss: 0.7645 - accuracy: 0.6515 - val_loss: 0.9236 - val_accuracy: 0.6000
# Epoch 38/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6952 - accuracy: 0.7061
# Epoch 38: val_loss did not improve from 0.89905
# 66/66 [==============================] - 6s 92ms/step - loss: 0.6952 - accuracy: 0.7061 - val_loss: 1.0596 - val_accuracy: 0.5846
# Epoch 39/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6466 - accuracy: 0.7182
# Epoch 39: val_loss did not improve from 0.89905
# 66/66 [==============================] - 5s 75ms/step - loss: 0.6466 - accuracy: 0.7182 - val_loss: 0.9784 - val_accuracy: 0.5692
# Epoch 40/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.7182
# Epoch 40: val_loss did not improve from 0.89905
# 66/66 [==============================] - 6s 91ms/step - loss: 0.6938 - accuracy: 0.7182 - val_loss: 1.0211 - val_accuracy: 0.5692
# Epoch 41/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6597 - accuracy: 0.7273
# Epoch 41: val_loss did not improve from 0.89905
# 66/66 [==============================] - 6s 95ms/step - loss: 0.6597 - accuracy: 0.7273 - val_loss: 0.9907 - val_accuracy: 0.6154
# Epoch 42/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6409 - accuracy: 0.7333
# Epoch 42: val_loss did not improve from 0.89905
# 66/66 [==============================] - 5s 76ms/step - loss: 0.6409 - accuracy: 0.7333 - val_loss: 1.0789 - val_accuracy: 0.5692
# Epoch 43/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6218 - accuracy: 0.7424
# Epoch 43: val_loss did not improve from 0.89905
# 66/66 [==============================] - 7s 105ms/step - loss: 0.6218 - accuracy: 0.7424 - val_loss: 0.9571 - val_accuracy: 0.6462
# Epoch 44/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6362 - accuracy: 0.7394
# Epoch 44: val_loss did not improve from 0.89905
# 66/66 [==============================] - 6s 85ms/step - loss: 0.6362 - accuracy: 0.7394 - val_loss: 1.0389 - val_accuracy: 0.6000
# Epoch 45/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6143 - accuracy: 0.7394
# Epoch 45: val_loss did not improve from 0.89905
# 66/66 [==============================] - 7s 100ms/step - loss: 0.6143 - accuracy: 0.7394 - val_loss: 0.9666 - val_accuracy: 0.5692
# Epoch 46/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6410 - accuracy: 0.7212
# Epoch 46: val_loss did not improve from 0.89905
# 66/66 [==============================] - 5s 75ms/step - loss: 0.6410 - accuracy: 0.7212 - val_loss: 0.9169 - val_accuracy: 0.5692
# Epoch 47/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6384 - accuracy: 0.7424
# Epoch 47: val_loss did not improve from 0.89905
# 66/66 [==============================] - 6s 95ms/step - loss: 0.6384 - accuracy: 0.7424 - val_loss: 1.0118 - val_accuracy: 0.5846
# Epoch 48/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6324 - accuracy: 0.7394
# Epoch 48: val_loss did not improve from 0.89905
# 66/66 [==============================] - 5s 76ms/step - loss: 0.6324 - accuracy: 0.7394 - val_loss: 0.9102 - val_accuracy: 0.5846
# Epoch 49/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5874 - accuracy: 0.7485
# Epoch 49: val_loss improved from 0.89905 to 0.81500, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 94ms/step - loss: 0.5874 - accuracy: 0.7485 - val_loss: 0.8150 - val_accuracy: 0.6154
# Epoch 50/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6336 - accuracy: 0.7333
# Epoch 50: val_loss did not improve from 0.81500
# 66/66 [==============================] - 5s 76ms/step - loss: 0.6336 - accuracy: 0.7333 - val_loss: 0.8461 - val_accuracy: 0.6615
# Epoch 51/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6104 - accuracy: 0.7364
# Epoch 51: val_loss did not improve from 0.81500
# 66/66 [==============================] - 7s 101ms/step - loss: 0.6104 - accuracy: 0.7364 - val_loss: 0.8467 - val_accuracy: 0.6462
# Epoch 52/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5710 - accuracy: 0.7848
# Epoch 52: val_loss did not improve from 0.81500
# 66/66 [==============================] - 6s 88ms/step - loss: 0.5710 - accuracy: 0.7848 - val_loss: 0.8506 - val_accuracy: 0.6308
# Epoch 53/100
# 66/66 [==============================] - ETA: 0s - loss: 0.6590 - accuracy: 0.7212
# Epoch 53: val_loss did not improve from 0.81500
# 66/66 [==============================] - 9s 132ms/step - loss: 0.6590 - accuracy: 0.7212 - val_loss: 0.8275 - val_accuracy: 0.6308
# Epoch 54/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5910 - accuracy: 0.7576
# Epoch 54: val_loss improved from 0.81500 to 0.77822, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 84ms/step - loss: 0.5910 - accuracy: 0.7576 - val_loss: 0.7782 - val_accuracy: 0.6769
# Epoch 55/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5909 - accuracy: 0.7667
# Epoch 55: val_loss improved from 0.77822 to 0.73002, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 105ms/step - loss: 0.5909 - accuracy: 0.7667 - val_loss: 0.7300 - val_accuracy: 0.6923
# Epoch 56/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5463 - accuracy: 0.7727
# Epoch 56: val_loss did not improve from 0.73002
# 66/66 [==============================] - 5s 82ms/step - loss: 0.5463 - accuracy: 0.7727 - val_loss: 0.8121 - val_accuracy: 0.6462
# Epoch 57/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5244 - accuracy: 0.7848
# Epoch 57: val_loss did not improve from 0.73002
# 66/66 [==============================] - 8s 116ms/step - loss: 0.5244 - accuracy: 0.7848 - val_loss: 0.7919 - val_accuracy: 0.6462
# Epoch 58/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5563 - accuracy: 0.7848
# Epoch 58: val_loss did not improve from 0.73002
# 66/66 [==============================] - 5s 74ms/step - loss: 0.5563 - accuracy: 0.7848 - val_loss: 0.8797 - val_accuracy: 0.5846
# Epoch 59/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5196 - accuracy: 0.7879
# Epoch 59: val_loss did not improve from 0.73002
# 66/66 [==============================] - 5s 77ms/step - loss: 0.5196 - accuracy: 0.7879 - val_loss: 0.7581 - val_accuracy: 0.6308
# Epoch 60/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5405 - accuracy: 0.7485
# Epoch 60: val_loss improved from 0.73002 to 0.65096, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 75ms/step - loss: 0.5405 - accuracy: 0.7485 - val_loss: 0.6510 - val_accuracy: 0.7538
# Epoch 61/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4530 - accuracy: 0.8242
# Epoch 61: val_loss did not improve from 0.65096
# 66/66 [==============================] - 6s 86ms/step - loss: 0.4530 - accuracy: 0.8242 - val_loss: 0.7317 - val_accuracy: 0.7077
# Epoch 62/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4706 - accuracy: 0.7879
# Epoch 62: val_loss did not improve from 0.65096
# 66/66 [==============================] - 7s 102ms/step - loss: 0.4706 - accuracy: 0.7879 - val_loss: 0.7576 - val_accuracy: 0.6769
# Epoch 63/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5888 - accuracy: 0.7424
# Epoch 63: val_loss did not improve from 0.65096
# 66/66 [==============================] - 5s 76ms/step - loss: 0.5888 - accuracy: 0.7424 - val_loss: 0.7338 - val_accuracy: 0.6615
# Epoch 64/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4691 - accuracy: 0.8121
# Epoch 64: val_loss did not improve from 0.65096
# 66/66 [==============================] - 6s 93ms/step - loss: 0.4691 - accuracy: 0.8121 - val_loss: 0.6759 - val_accuracy: 0.6923
# Epoch 65/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5032 - accuracy: 0.8061
# Epoch 65: val_loss improved from 0.65096 to 0.62297, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 81ms/step - loss: 0.5032 - accuracy: 0.8061 - val_loss: 0.6230 - val_accuracy: 0.7077
# Epoch 66/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4603 - accuracy: 0.8030
# Epoch 66: val_loss did not improve from 0.62297
# 66/66 [==============================] - 6s 95ms/step - loss: 0.4603 - accuracy: 0.8030 - val_loss: 0.7800 - val_accuracy: 0.6615
# Epoch 67/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5063 - accuracy: 0.7909
# Epoch 67: val_loss did not improve from 0.62297
# 66/66 [==============================] - 5s 75ms/step - loss: 0.5063 - accuracy: 0.7909 - val_loss: 0.7553 - val_accuracy: 0.7077
# Epoch 68/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4710 - accuracy: 0.7848
# Epoch 68: val_loss did not improve from 0.62297
# 66/66 [==============================] - 7s 103ms/step - loss: 0.4710 - accuracy: 0.7848 - val_loss: 0.6584 - val_accuracy: 0.7231
# Epoch 69/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4424 - accuracy: 0.8303
# Epoch 69: val_loss did not improve from 0.62297
# 66/66 [==============================] - 5s 74ms/step - loss: 0.4424 - accuracy: 0.8303 - val_loss: 0.6623 - val_accuracy: 0.7385
# Epoch 70/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4397 - accuracy: 0.8121
# Epoch 70: val_loss did not improve from 0.62297
# 66/66 [==============================] - 6s 91ms/step - loss: 0.4397 - accuracy: 0.8121 - val_loss: 0.7256 - val_accuracy: 0.7231
# Epoch 71/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4341 - accuracy: 0.8242
# Epoch 71: val_loss improved from 0.62297 to 0.61006, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 76ms/step - loss: 0.4341 - accuracy: 0.8242 - val_loss: 0.6101 - val_accuracy: 0.7231
# Epoch 72/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4181 - accuracy: 0.8636
# Epoch 72: val_loss did not improve from 0.61006
# 66/66 [==============================] - 7s 102ms/step - loss: 0.4181 - accuracy: 0.8636 - val_loss: 0.7022 - val_accuracy: 0.7692
# Epoch 73/100
# 66/66 [==============================] - ETA: 0s - loss: 0.5141 - accuracy: 0.7636
# Epoch 73: val_loss improved from 0.61006 to 0.60036, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 92ms/step - loss: 0.5141 - accuracy: 0.7636 - val_loss: 0.6004 - val_accuracy: 0.8000
# Epoch 74/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.8545
# Epoch 74: val_loss did not improve from 0.60036
# 66/66 [==============================] - 6s 97ms/step - loss: 0.3971 - accuracy: 0.8545 - val_loss: 0.6111 - val_accuracy: 0.7231
# Epoch 75/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4208 - accuracy: 0.8545
# Epoch 75: val_loss did not improve from 0.60036
# 66/66 [==============================] - 6s 91ms/step - loss: 0.4208 - accuracy: 0.8545 - val_loss: 0.6778 - val_accuracy: 0.6769
# Epoch 76/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4044 - accuracy: 0.8455
# Epoch 76: val_loss improved from 0.60036 to 0.57872, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 90ms/step - loss: 0.4044 - accuracy: 0.8455 - val_loss: 0.5787 - val_accuracy: 0.7538
# Epoch 77/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3681 - accuracy: 0.8697
# Epoch 77: val_loss did not improve from 0.57872
# 66/66 [==============================] - 7s 100ms/step - loss: 0.3681 - accuracy: 0.8697 - val_loss: 0.6202 - val_accuracy: 0.7846
# Epoch 78/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3867 - accuracy: 0.8485
# Epoch 78: val_loss improved from 0.57872 to 0.55718, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 83ms/step - loss: 0.3867 - accuracy: 0.8485 - val_loss: 0.5572 - val_accuracy: 0.7692
# Epoch 79/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4242 - accuracy: 0.8394
# Epoch 79: val_loss did not improve from 0.55718
# 66/66 [==============================] - 7s 105ms/step - loss: 0.4242 - accuracy: 0.8394 - val_loss: 0.6249 - val_accuracy: 0.7538
# Epoch 80/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3985 - accuracy: 0.8758
# Epoch 80: val_loss did not improve from 0.55718
# 66/66 [==============================] - 5s 74ms/step - loss: 0.3985 - accuracy: 0.8758 - val_loss: 0.5723 - val_accuracy: 0.7846
# Epoch 81/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4015 - accuracy: 0.8455
# Epoch 81: val_loss did not improve from 0.55718
# 66/66 [==============================] - 6s 96ms/step - loss: 0.4015 - accuracy: 0.8455 - val_loss: 0.5590 - val_accuracy: 0.7538
# Epoch 82/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3886 - accuracy: 0.8455
# Epoch 82: val_loss did not improve from 0.55718
# 66/66 [==============================] - 5s 76ms/step - loss: 0.3886 - accuracy: 0.8455 - val_loss: 0.6292 - val_accuracy: 0.7538
# Epoch 83/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3848 - accuracy: 0.8455
# Epoch 83: val_loss improved from 0.55718 to 0.55308, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 101ms/step - loss: 0.3848 - accuracy: 0.8455 - val_loss: 0.5531 - val_accuracy: 0.7538
# Epoch 84/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3694 - accuracy: 0.8515
# Epoch 84: val_loss improved from 0.55308 to 0.47450, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 6s 95ms/step - loss: 0.3694 - accuracy: 0.8515 - val_loss: 0.4745 - val_accuracy: 0.7692
# Epoch 85/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3474 - accuracy: 0.8788
# Epoch 85: val_loss did not improve from 0.47450
# 66/66 [==============================] - 5s 75ms/step - loss: 0.3474 - accuracy: 0.8788 - val_loss: 0.5091 - val_accuracy: 0.7692
# Epoch 86/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3217 - accuracy: 0.8818
# Epoch 86: val_loss did not improve from 0.47450
# 66/66 [==============================] - 6s 98ms/step - loss: 0.3217 - accuracy: 0.8818 - val_loss: 0.5032 - val_accuracy: 0.7846
# Epoch 87/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3670 - accuracy: 0.8545
# Epoch 87: val_loss did not improve from 0.47450
# 66/66 [==============================] - 5s 75ms/step - loss: 0.3670 - accuracy: 0.8545 - val_loss: 0.5986 - val_accuracy: 0.7538
# Epoch 88/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3790 - accuracy: 0.8606
# Epoch 88: val_loss did not improve from 0.47450
# 66/66 [==============================] - 7s 105ms/step - loss: 0.3790 - accuracy: 0.8606 - val_loss: 0.6057 - val_accuracy: 0.7538
# Epoch 89/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4083 - accuracy: 0.8273
# Epoch 89: val_loss did not improve from 0.47450
# 66/66 [==============================] - 6s 87ms/step - loss: 0.4083 - accuracy: 0.8273 - val_loss: 0.5720 - val_accuracy: 0.8000
# Epoch 90/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3551 - accuracy: 0.8515
# Epoch 90: val_loss did not improve from 0.47450
# 66/66 [==============================] - 7s 109ms/step - loss: 0.3551 - accuracy: 0.8515 - val_loss: 0.5265 - val_accuracy: 0.7846
# Epoch 91/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8697
# Epoch 91: val_loss improved from 0.47450 to 0.45158, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 5s 76ms/step - loss: 0.3972 - accuracy: 0.8697 - val_loss: 0.4516 - val_accuracy: 0.7846
# Epoch 92/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3354 - accuracy: 0.8788
# Epoch 92: val_loss improved from 0.45158 to 0.44989, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 107ms/step - loss: 0.3354 - accuracy: 0.8788 - val_loss: 0.4499 - val_accuracy: 0.8000
# Epoch 93/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3282 - accuracy: 0.8848
# Epoch 93: val_loss did not improve from 0.44989
# 66/66 [==============================] - 6s 87ms/step - loss: 0.3282 - accuracy: 0.8848 - val_loss: 0.5068 - val_accuracy: 0.8000
# Epoch 94/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3394 - accuracy: 0.8636
# Epoch 94: val_loss did not improve from 0.44989
# 66/66 [==============================] - 5s 76ms/step - loss: 0.3394 - accuracy: 0.8636 - val_loss: 0.6064 - val_accuracy: 0.7538
# Epoch 95/100
# 66/66 [==============================] - ETA: 0s - loss: 0.4039 - accuracy: 0.8364
# Epoch 95: val_loss improved from 0.44989 to 0.42100, saving model to infantface_checkpoint.ckpt
# 66/66 [==============================] - 7s 110ms/step - loss: 0.4039 - accuracy: 0.8364 - val_loss: 0.4210 - val_accuracy: 0.8154
# Epoch 96/100
# 66/66 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.8909
# Epoch 96: val_loss did not improve from 0.42100
# 66/66 [==============================] - 5s 82ms/step - loss: 0.2795 - accuracy: 0.8909 - val_loss: 0.4620 - val_accuracy: 0.8462
# Epoch 97/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3343 - accuracy: 0.8606
# Epoch 97: val_loss did not improve from 0.42100
# 66/66 [==============================] - 7s 108ms/step - loss: 0.3343 - accuracy: 0.8606 - val_loss: 0.4310 - val_accuracy: 0.8000
# Epoch 98/100
# 66/66 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.8848
# Epoch 98: val_loss did not improve from 0.42100
# 66/66 [==============================] - 5s 77ms/step - loss: 0.2812 - accuracy: 0.8848 - val_loss: 0.4216 - val_accuracy: 0.8000
# Epoch 99/100
# 66/66 [==============================] - ETA: 0s - loss: 0.2853 - accuracy: 0.9000
# Epoch 99: val_loss did not improve from 0.42100
# 66/66 [==============================] - 8s 124ms/step - loss: 0.2853 - accuracy: 0.9000 - val_loss: 0.5566 - val_accuracy: 0.8154
# Epoch 100/100
# 66/66 [==============================] - ETA: 0s - loss: 0.3103 - accuracy: 0.8970
# Epoch 100: val_loss did not improve from 0.42100
# 66/66 [==============================] - 6s 84ms/step - loss: 0.3103 - accuracy: 0.8970 - val_loss: 0.5804 - val_accuracy: 0.8000
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# 결과 그래프를 그려보아요!

fig = plt.figure()

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(history.history['loss'], color='r')
ax1.plot(history.history['val_loss'], color='b')

ax2.plot(history.history['accuracy'], color='r')
ax2.plot(history.history['val_accuracy'], color='b')

plt.tight_layout()
plt.show()

# %% [markdown]
# - 학습 데이터가 부족할 때, 데이터의 양을 늘리기 위해 증식을 사용
# - 이는 overfitting을 줄이는 것
# - 이 모델 자체의 accuracy를 높이는 것은 아님
#
# **이를 해결하기 위해 바로 아래의 Pretrained Network를 이용해야 한다**

# %% [markdown]
# ## Pretrained Network 이용
# - accuracy를 높이기 위해서 전이학습을 실시한다

# %% [markdown]
# ### Efficient 사용
# - VGG16보다 성능이 더 좋은 Efficient를 이용해서 Transfer Learning을 진행해서 결과 비교

# %%
# EfficientNet을 설치부터 진행!
# !pip install efficientnet
# Out:
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.11.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (23.2)
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8

# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.22.0 typeguard-2.13.3

# %%
# 필요한 module import
import numpy as np
import matplotlib.pyplot as plt
import efficientnet
import efficientnet.tfkeras as efn
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import cv2

# %%
#  dir 불러오기
train_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/train'
validation_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/valid'

# %%
IMAGE_SIZE = 150  # 이 이미지의 크기는 일반적으로 pretrained network을
                  # 어떤 종류를 사용하는냐에 따라서 결정되요!
BATCH_SIZE = 5

# %%
# 이미지 전처리에 대한 함수예요. 여기서는 resize만 처리할꺼예요!
def GeneratePreprocess(img):
    img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
    return img

# Augmentation 포함해서 ImageDataGenerator를 생성(train).
train_datagen = ImageDataGenerator(rescale=1/255,
                                   rotation_range=30,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   preprocessing_function=GeneratePreprocess,
                                   fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1/255,
                                        preprocessing_function=GeneratePreprocess)

# %%
# ImageDataGenerator 객체 세부 설정

train_generator = train_datagen.flow_from_directory(
    train_dir,
    classes=['positive', 'neutral', 'negative'],
    target_size=(150, 150),
    batch_size=5,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    classes=['positive', 'neutral', 'negative'],
    target_size=(150, 150),
    batch_size=5,
    class_mode='categorical'
)
# Out:
# Found 330 images belonging to 3 classes.
# Found 65 images belonging to 3 classes.

# %%
# Pretrained Network Loading

pretrained_model = efn.EfficientNetB4(
    weights='imagenet',
    include_top=False,
    input_shape=(IMAGE_SIZE,IMAGE_SIZE,3)
)
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b4_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 71892840/71892840 [==============================] - 1s 0us/step

# %%
pretrained_model.trainable = False

pretrained_model.summary()
# Out:
# Model: "efficientnet-b4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  stem_conv (Conv2D)          (None, 75, 75, 48)           1296      ['input_1[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 75, 75, 48)           192       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 75, 75, 48)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 75, 75, 48)           432       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 75, 75, 48)           192       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 75, 75, 48)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 48)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 48)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 12)             588       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 48)             624       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 75, 75, 48)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 75, 75, 24)           1152      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 75, 75, 24)           96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 75, 75, 24)           216       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 75, 75, 24)           96        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 75, 75, 24)           0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 24)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 75, 75, 24)           0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 75, 75, 24)           576       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 75, 75, 24)           96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (FixedDropout  (None, 75, 75, 24)           0         ['block1b_project_bn[0][0]']
#  )
#
#  block1b_add (Add)           (None, 75, 75, 24)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 144)          3456      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 144)          576       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 144)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv (DepthwiseC  (None, 38, 38, 144)          1296      ['block2a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2a_bn (BatchNormaliza  (None, 38, 38, 144)          576       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 38, 38, 144)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 144)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 38, 38, 144)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 38, 38, 32)           4608      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 38, 38, 32)           128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 38, 38, 192)          6144      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 38, 38, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 38, 38, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 38, 38, 192)          1728      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 38, 38, 192)          768       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 38, 38, 192)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 192)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 38, 38, 192)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 38, 38, 32)           6144      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 38, 38, 32)           128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (FixedDropout  (None, 38, 38, 32)           0         ['block2b_project_bn[0][0]']
#  )
#
#  block2b_add (Add)           (None, 38, 38, 32)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 38, 38, 192)          6144      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 38, 38, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 38, 38, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 38, 38, 192)          1728      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 38, 38, 192)          768       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 38, 38, 192)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 192)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 38, 38, 192)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 38, 38, 32)           6144      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 38, 38, 32)           128       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (FixedDropout  (None, 38, 38, 32)           0         ['block2c_project_bn[0][0]']
#  )
#
#  block2c_add (Add)           (None, 38, 38, 32)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 38, 38, 192)          6144      ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 38, 38, 192)          768       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 38, 38, 192)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 38, 38, 192)          1728      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 38, 38, 192)          768       ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 38, 38, 192)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 192)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 38, 38, 192)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 38, 38, 32)           6144      ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 38, 38, 32)           128       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (FixedDropout  (None, 38, 38, 32)           0         ['block2d_project_bn[0][0]']
#  )
#
#  block2d_add (Add)           (None, 38, 38, 32)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 192)          6144      ['block2d_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv (DepthwiseC  (None, 19, 19, 192)          4800      ['block3a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3a_bn (BatchNormaliza  (None, 19, 19, 192)          768       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 19, 19, 192)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 192)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 19, 19, 192)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 19, 19, 56)           10752     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 19, 19, 56)           224       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 19, 19, 336)          18816     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 19, 19, 336)          1344      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 19, 19, 336)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 19, 19, 336)          8400      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 19, 19, 336)          1344      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 19, 19, 336)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 336)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 19, 19, 336)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 19, 19, 56)           18816     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 19, 19, 56)           224       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (FixedDropout  (None, 19, 19, 56)           0         ['block3b_project_bn[0][0]']
#  )
#
#  block3b_add (Add)           (None, 19, 19, 56)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 19, 19, 336)          18816     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 19, 19, 336)          1344      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 19, 19, 336)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 19, 19, 336)          8400      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 19, 19, 336)          1344      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 19, 19, 336)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 336)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 19, 19, 336)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 19, 19, 56)           18816     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 19, 19, 56)           224       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (FixedDropout  (None, 19, 19, 56)           0         ['block3c_project_bn[0][0]']
#  )
#
#  block3c_add (Add)           (None, 19, 19, 56)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 19, 19, 336)          18816     ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 19, 19, 336)          1344      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 19, 19, 336)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_dwconv (DepthwiseC  (None, 19, 19, 336)          8400      ['block3d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3d_bn (BatchNormaliza  (None, 19, 19, 336)          1344      ['block3d_dwconv[0][0]']
#  tion)
#
#  block3d_activation (Activa  (None, 19, 19, 336)          0         ['block3d_bn[0][0]']
#  tion)
#
#  block3d_se_squeeze (Global  (None, 336)                  0         ['block3d_activation[0][0]']
#  AveragePooling2D)
#
#  block3d_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block3d_se_squeeze[0][0]']
#  e)
#
#  block3d_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multipl  (None, 19, 19, 336)          0         ['block3d_activation[0][0]',
#  y)                                                                  'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv  (None, 19, 19, 56)           18816     ['block3d_se_excite[0][0]']
#  2D)
#
#  block3d_project_bn (BatchN  (None, 19, 19, 56)           224       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (FixedDropout  (None, 19, 19, 56)           0         ['block3d_project_bn[0][0]']
#  )
#
#  block3d_add (Add)           (None, 19, 19, 56)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 19, 19, 336)          18816     ['block3d_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 19, 19, 336)          1344      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 19, 19, 336)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv (DepthwiseC  (None, 10, 10, 336)          3024      ['block4a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4a_bn (BatchNormaliza  (None, 10, 10, 336)          1344      ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 10, 10, 336)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 336)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 10, 10, 336)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 10, 10, 112)          37632     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 10, 10, 112)          448       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 10, 10, 672)          75264     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 10, 10, 672)          2688      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 10, 10, 672)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 10, 10, 672)          6048      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 10, 10, 672)          2688      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 10, 10, 672)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 672)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 10, 10, 672)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 10, 10, 112)          75264     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 10, 10, 112)          448       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (FixedDropout  (None, 10, 10, 112)          0         ['block4b_project_bn[0][0]']
#  )
#
# ...
#  tion)
#
#  block6g_se_squeeze (Global  (None, 1632)                 0         ['block6g_activation[0][0]']
#  AveragePooling2D)
#
#  block6g_se_reshape (Reshap  (None, 1, 1, 1632)           0         ['block6g_se_squeeze[0][0]']
#  e)
#
#  block6g_se_reduce (Conv2D)  (None, 1, 1, 68)             111044    ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)  (None, 1, 1, 1632)           112608    ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multipl  (None, 5, 5, 1632)           0         ['block6g_activation[0][0]',
#  y)                                                                  'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv  (None, 5, 5, 272)            443904    ['block6g_se_excite[0][0]']
#  2D)
#
#  block6g_project_bn (BatchN  (None, 5, 5, 272)            1088      ['block6g_project_conv[0][0]']
#  ormalization)
#
#  block6g_drop (FixedDropout  (None, 5, 5, 272)            0         ['block6g_project_bn[0][0]']
#  )
#
#  block6g_add (Add)           (None, 5, 5, 272)            0         ['block6g_drop[0][0]',
#                                                                      'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2  (None, 5, 5, 1632)           443904    ['block6g_add[0][0]']
#  D)
#
#  block6h_expand_bn (BatchNo  (None, 5, 5, 1632)           6528      ['block6h_expand_conv[0][0]']
#  rmalization)
#
#  block6h_expand_activation   (None, 5, 5, 1632)           0         ['block6h_expand_bn[0][0]']
#  (Activation)
#
#  block6h_dwconv (DepthwiseC  (None, 5, 5, 1632)           40800     ['block6h_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6h_bn (BatchNormaliza  (None, 5, 5, 1632)           6528      ['block6h_dwconv[0][0]']
#  tion)
#
#  block6h_activation (Activa  (None, 5, 5, 1632)           0         ['block6h_bn[0][0]']
#  tion)
#
#  block6h_se_squeeze (Global  (None, 1632)                 0         ['block6h_activation[0][0]']
#  AveragePooling2D)
#
#  block6h_se_reshape (Reshap  (None, 1, 1, 1632)           0         ['block6h_se_squeeze[0][0]']
#  e)
#
#  block6h_se_reduce (Conv2D)  (None, 1, 1, 68)             111044    ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)  (None, 1, 1, 1632)           112608    ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multipl  (None, 5, 5, 1632)           0         ['block6h_activation[0][0]',
#  y)                                                                  'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv  (None, 5, 5, 272)            443904    ['block6h_se_excite[0][0]']
#  2D)
#
#  block6h_project_bn (BatchN  (None, 5, 5, 272)            1088      ['block6h_project_conv[0][0]']
#  ormalization)
#
#  block6h_drop (FixedDropout  (None, 5, 5, 272)            0         ['block6h_project_bn[0][0]']
#  )
#
#  block6h_add (Add)           (None, 5, 5, 272)            0         ['block6h_drop[0][0]',
#                                                                      'block6g_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 5, 5, 1632)           443904    ['block6h_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 5, 5, 1632)           6528      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 5, 5, 1632)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 5, 5, 1632)           14688     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 5, 5, 1632)           6528      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 5, 5, 1632)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1632)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1632)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 68)             111044    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1632)           112608    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 5, 5, 1632)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 5, 5, 448)            731136    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 5, 5, 448)            1792      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 5, 5, 2688)           1204224   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 5, 5, 2688)           10752     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 5, 5, 2688)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 5, 5, 2688)           24192     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 5, 5, 2688)           10752     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 5, 5, 2688)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 2688)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 2688)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 112)            301168    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 2688)           303744    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 5, 5, 2688)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 5, 5, 448)            1204224   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 5, 5, 448)            1792      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (FixedDropout  (None, 5, 5, 448)            0         ['block7b_project_bn[0][0]']
#  )
#
#  block7b_add (Add)           (None, 5, 5, 448)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)           (None, 5, 5, 1792)           802816    ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 5, 5, 1792)           7168      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 5, 5, 1792)           0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 17673816 (67.42 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 17673816 (67.42 MB)
# __________________________________________________________________________________________________

# %%
# Model 구현
model = Sequential()

model.add(pretrained_model)

model.add(Flatten(input_shape=(8*8*1792,)))
model.add(Dense(units=3,
                activation='softmax'))

es = EarlyStopping(monitor='val_loss',
                   patience=5,
                   verbose=1)

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_generator,
                    steps_per_epoch=66,
                    epochs=100,
                    verbose=1,
                    validation_data=validation_generator,
                    validation_steps=13)

model.save('./infantface_IDG_cnn_Eff_model.h5')
# Out:
# Epoch 1/100
# 66/66 [==============================] - 146s 2s/step - loss: 0.9574 - accuracy: 0.5636 - val_loss: 0.8115 - val_accuracy: 0.6615
# Epoch 2/100
# 66/66 [==============================] - 8s 115ms/step - loss: 0.8412 - accuracy: 0.6333 - val_loss: 0.8301 - val_accuracy: 0.6308
# Epoch 3/100
# 66/66 [==============================] - 6s 92ms/step - loss: 0.6649 - accuracy: 0.6970 - val_loss: 0.8317 - val_accuracy: 0.6308
# Epoch 4/100
# 66/66 [==============================] - 8s 120ms/step - loss: 0.6753 - accuracy: 0.7212 - val_loss: 0.8469 - val_accuracy: 0.6154
# Epoch 5/100
# 66/66 [==============================] - 6s 87ms/step - loss: 0.6526 - accuracy: 0.7394 - val_loss: 0.6488 - val_accuracy: 0.7077
# Epoch 6/100
# 66/66 [==============================] - 7s 105ms/step - loss: 0.5519 - accuracy: 0.7848 - val_loss: 0.6232 - val_accuracy: 0.7231
# Epoch 7/100
# 66/66 [==============================] - 6s 95ms/step - loss: 0.5496 - accuracy: 0.7727 - val_loss: 0.7658 - val_accuracy: 0.6769
# Epoch 8/100
# 66/66 [==============================] - 8s 126ms/step - loss: 0.5171 - accuracy: 0.7909 - val_loss: 0.5200 - val_accuracy: 0.7846
# Epoch 9/100
# 66/66 [==============================] - 6s 87ms/step - loss: 0.4496 - accuracy: 0.8182 - val_loss: 1.0046 - val_accuracy: 0.6000
# 66/66 [==============================] - 8s 116ms/step - loss: 0.2061 - accuracy: 0.9182 - val_loss: 0.2912 - val_accuracy: 0.8615
# Epoch 88/100
# 66/66 [==============================] - 7s 99ms/step - loss: 0.2101 - accuracy: 0.9242 - val_loss: 0.3801 - val_accuracy: 0.8462
# Epoch 89/100
# 66/66 [==============================] - 6s 97ms/step - loss: 0.2762 - accuracy: 0.8939 - val_loss: 0.3815 - val_accuracy: 0.8615
# Epoch 90/100
# 66/66 [==============================] - 6s 86ms/step - loss: 0.2105 - accuracy: 0.9212 - val_loss: 0.3775 - val_accuracy: 0.8462
# Epoch 91/100
# 66/66 [==============================] - 7s 108ms/step - loss: 0.2651 - accuracy: 0.8879 - val_loss: 0.3786 - val_accuracy: 0.8308
# Epoch 92/100
# 66/66 [==============================] - 6s 86ms/step - loss: 0.2115 - accuracy: 0.9182 - val_loss: 0.3325 - val_accuracy: 0.8308
# Epoch 93/100
# 66/66 [==============================] - 8s 123ms/step - loss: 0.1427 - accuracy: 0.9576 - val_loss: 0.4899 - val_accuracy: 0.8308
# Epoch 94/100
# 66/66 [==============================] - 6s 85ms/step - loss: 0.2326 - accuracy: 0.9030 - val_loss: 0.4602 - val_accuracy: 0.8462
# Epoch 95/100
# 66/66 [==============================] - 6s 96ms/step - loss: 0.2086 - accuracy: 0.9030 - val_loss: 0.3140 - val_accuracy: 0.8462
# Epoch 96/100
# 66/66 [==============================] - 6s 85ms/step - loss: 0.2056 - accuracy: 0.9303 - val_loss: 0.4140 - val_accuracy: 0.8308
# Epoch 97/100
# 66/66 [==============================] - 7s 107ms/step - loss: 0.1693 - accuracy: 0.9364 - val_loss: 0.3132 - val_accuracy: 0.8923
# Epoch 98/100
# 66/66 [==============================] - 6s 85ms/step - loss: 0.2106 - accuracy: 0.9242 - val_loss: 0.5067 - val_accuracy: 0.8154
# Epoch 99/100
# 66/66 [==============================] - 7s 100ms/step - loss: 0.1839 - accuracy: 0.9364 - val_loss: 0.3116 - val_accuracy: 0.8769
# Epoch 100/100
# 66/66 [==============================] - 5s 83ms/step - loss: 0.1777 - accuracy: 0.9242 - val_loss: 0.3765 - val_accuracy: 0.8462
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# 결과 그래프를 그려보아요!

fig = plt.figure()

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(history.history['loss'], color='r')
ax1.plot(history.history['val_loss'], color='b')

ax2.plot(history.history['accuracy'], color='r')
ax2.plot(history.history['val_accuracy'], color='b')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test 진행

# %%
# 테스트에 필요한 module import
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

# %%
# 저장된 모델 파일의 경로
saved_model_path = '/content/infantface_IDG_cnn_Eff_model.h5'

# 테스트할 이미지 경로 설정
test_image_path = '/content/drive/MyDrive/KOSA3/project/data/test_pos2.png'

# 모델 로드
loaded_model = load_model(saved_model_path)

# 이미지 불러오기 및 전처리
img = image.load_img(test_image_path, target_size=(150, 150))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
# 모델 예측
predictions = loaded_model.predict(img_array)

# 예측 결과 해석 및 출력
class_indices = np.argmax(predictions, axis=1)

# 각 클래스의 인덱스에 따른 레이블 설정 (positive, neutral, negative)
class_labels = ['positive', 'neutral', 'negative']
predicted_label = class_labels[class_indices[0]]

print(f"Predicted Class: {predicted_label}")
# Out:
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7bd92dd540d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# Predicted Class: negative

# %% [markdown]
# ### Fine-Tuning

# %% [markdown]
# ------------------------------------------------------------------------
# 위처럼 한 번 학습을 진행한 후
#
# 여러개의 레이어를 한 번씩 for 문으로 돌면서
# 내가 원하는 레이어의 설정한 살짝씩 바꿔주는 작업이 필요!
#
# ------------------------------------------------------------------------

# %%
# 필요한 module import
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
#  dir 불러오기
train_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/train'
validation_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/valid'

# %%
# 일단 이렇게 학습을 한번 진행해야 해요!

# Convolution Layer 동결해제
pretrained_model.trainable = True

# 그런다음 classifier에서 가까운 쪽에 있는 Convolution Layer의
# Filter들만 update가 가능하고 나머지는 update가 안되도록 다시 설정

for layer in pretrained_model.layers:
    if layer.name in ['block5_conv1', 'block5_conv2', 'block5_conv3']:
        layer.trainable = True
    else:
        layer.trainable = False

# 미세조정(Fine Tuning)을 진행한 후 다시 학습에 대한 설정을 하고
# 재 학습 진행!
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_generator,
                    steps_per_epoch=66,
                    epochs=50,
                    validation_data=validation_generator,
                    validation_steps=13,
                    verbose=1)
# Out:
# Epoch 1/50
# 66/66 [==============================] - 53s 154ms/step - loss: 0.1651 - accuracy: 0.9455 - val_loss: 0.2991 - val_accuracy: 0.8462
# Epoch 2/50
# 66/66 [==============================] - 5s 82ms/step - loss: 0.1761 - accuracy: 0.9424 - val_loss: 0.4095 - val_accuracy: 0.8308
# Epoch 3/50
# 66/66 [==============================] - 7s 113ms/step - loss: 0.1570 - accuracy: 0.9364 - val_loss: 0.2933 - val_accuracy: 0.8769
# Epoch 4/50
# 66/66 [==============================] - 6s 92ms/step - loss: 0.1583 - accuracy: 0.9606 - val_loss: 0.2898 - val_accuracy: 0.8769
# Epoch 5/50
# 66/66 [==============================] - 8s 114ms/step - loss: 0.0961 - accuracy: 0.9758 - val_loss: 0.3138 - val_accuracy: 0.8462
# Epoch 6/50
# 66/66 [==============================] - 5s 81ms/step - loss: 0.1352 - accuracy: 0.9667 - val_loss: 0.2874 - val_accuracy: 0.8462
# Epoch 7/50
# 66/66 [==============================] - 7s 106ms/step - loss: 0.1350 - accuracy: 0.9667 - val_loss: 0.3286 - val_accuracy: 0.8462
# Epoch 8/50
# 66/66 [==============================] - 6s 90ms/step - loss: 0.1289 - accuracy: 0.9606 - val_loss: 0.3776 - val_accuracy: 0.8462
# Epoch 9/50
# 66/66 [==============================] - 6s 91ms/step - loss: 0.1659 - accuracy: 0.9333 - val_loss: 0.2839 - val_accuracy: 0.8615
# Epoch 10/50
# 66/66 [==============================] - 5s 82ms/step - loss: 0.1126 - accuracy: 0.9667 - val_loss: 0.3515 - val_accuracy: 0.8308
# Epoch 11/50
# 66/66 [==============================] - 6s 96ms/step - loss: 0.1000 - accuracy: 0.9697 - val_loss: 0.3346 - val_accuracy: 0.8462
# Epoch 12/50
# 66/66 [==============================] - 6s 92ms/step - loss: 0.1508 - accuracy: 0.9364 - val_loss: 0.2614 - val_accuracy: 0.8923
# Epoch 13/50
# 66/66 [==============================] - 8s 115ms/step - loss: 0.1320 - accuracy: 0.9515 - val_loss: 0.3266 - val_accuracy: 0.8462
50
# 66/66 [==============================] - 5s 82ms/step - loss: 0.1576 - accuracy: 0.9455 - val_loss: 0.2716 - val_accuracy: 0.8769
# Epoch 36/50
# 66/66 [==============================] - 6s 97ms/step - loss: 0.1157 - accuracy: 0.9636 - val_loss: 0.3223 - val_accuracy: 0.8462
# Epoch 37/50
# 66/66 [==============================] - 5s 82ms/step - loss: 0.1076 - accuracy: 0.9697 - val_loss: 0.2727 - val_accuracy: 0.8769
# Epoch 38/50
# 66/66 [==============================] - 7s 109ms/step - loss: 0.1476 - accuracy: 0.9485 - val_loss: 0.2804 - val_accuracy: 0.8615
# Epoch 39/50
# 66/66 [==============================] - 5s 82ms/step - loss: 0.1217 - accuracy: 0.9576 - val_loss: 0.2879 - val_accuracy: 0.8769
# Epoch 40/50
# 66/66 [==============================] - 7s 104ms/step - loss: 0.1524 - accuracy: 0.9424 - val_loss: 0.2743 - val_accuracy: 0.8769
# Epoch 41/50
# 66/66 [==============================] - 6s 91ms/step - loss: 0.1329 - accuracy: 0.9667 - val_loss: 0.3181 - val_accuracy: 0.8462
# Epoch 42/50
# 66/66 [==============================] - 6s 87ms/step - loss: 0.1450 - accuracy: 0.9545 - val_loss: 0.3276 - val_accuracy: 0.8462
# Epoch 43/50
# 66/66 [==============================] - 8s 124ms/step - loss: 0.1361 - accuracy: 0.9515 - val_loss: 0.2428 - val_accuracy: 0.9077
# Epoch 44/50
# 66/66 [==============================] - 5s 82ms/step - loss: 0.1424 - accuracy: 0.9576 - val_loss: 0.3501 - val_accuracy: 0.8308
# Epoch 45/50
# 66/66 [==============================] - 7s 108ms/step - loss: 0.1276 - accuracy: 0.9667 - val_loss: 0.2809 - val_accuracy: 0.8462
# Epoch 46/50
# 66/66 [==============================] - 6s 84ms/step - loss: 0.1563 - accuracy: 0.9455 - val_loss: 0.2868 - val_accuracy: 0.8462
# Epoch 47/50
# 66/66 [==============================] - 8s 120ms/step - loss: 0.1022 - accuracy: 0.9727 - val_loss: 0.2794 - val_accuracy: 0.8615
# Epoch 48/50
# 66/66 [==============================] - 5s 81ms/step - loss: 0.1456 - accuracy: 0.9424 - val_loss: 0.2449 - val_accuracy: 0.8923
# Epoch 49/50
# 66/66 [==============================] - 6s 93ms/step - loss: 0.1380 - accuracy: 0.9424 - val_loss: 0.3456 - val_accuracy: 0.8308
# Epoch 50/50
# 66/66 [==============================] - 7s 107ms/step - loss: 0.1327 - accuracy: 0.9576 - val_loss: 0.2836 - val_accuracy: 0.8615

# %%
# 그런다음 classifier에서 가까운 쪽에 있는 Convolution Layer의
# Filter들만 update가 가능하고 나머지는 update가 안되도록 다시 설정

# for layer in model_base.layers:
#     if layer.name in ['aa', 'bb', 'cc']:
#         layer.trainable = True
#     else:
#         layer.trainable = False
# aa, bb, cc에 들어올 이름들은 model.summary()로 알게된 레이어의 이름들이다.

# 이런식으로 Fine_Tuning을 해준다
# 모델을 땅땅땅 내가 원하는 식으로 살짝씩 바꿔서 제어해서 사용해준다

for layer in pretrained_model.layers:
    if layer.name in ['block5_conv1', 'block5_conv2', 'block5_conv3']:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
# 미세조정(Fine Tuning)을 진행한 후 다시 학습에 대한 설정을 하고
# 재 학습 진행!
model.compile(optimizer=Adam(learning_rate=1e-5), # # 미세 조정해주었으니 조금 작은 값을 주어도 된다!
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_generator,
                    steps_per_epoch=66,
                    epochs=50,
                    validation_data=validation_generator,
                    validation_steps=13,
                    verbose=1)# Convolution Layer 동결해제

pretrained_model.trainable = True

#model.save  ``
# Out:
# Epoch 1/50
# 66/66 [==============================] - 21s 116ms/step - loss: 0.1166 - accuracy: 0.9636 - val_loss: 0.2952 - val_accuracy: 0.8462
# Epoch 2/50
# 66/66 [==============================] - 8s 116ms/step - loss: 0.1236 - accuracy: 0.9515 - val_loss: 0.2783 - val_accuracy: 0.8769
# Epoch 3/50
# 66/66 [==============================] - 5s 83ms/step - loss: 0.1280 - accuracy: 0.9515 - val_loss: 0.3273 - val_accuracy: 0.8462
# Epoch 4/50
# 66/66 [==============================] - 7s 107ms/step - loss: 0.1170 - accuracy: 0.9727 - val_loss: 0.2989 - val_accuracy: 0.8462
# Epoch 5/50
# 66/66 [==============================] - 5s 81ms/step - loss: 0.1389 - accuracy: 0.9515 - val_loss: 0.3099 - val_accuracy: 0.8462
# Epoch 6/50
# 66/66 [==============================] - 7s 110ms/step - loss: 0.1393 - accuracy: 0.9576 - val_loss: 0.3197 - val_accuracy: 0.8615
# Epoch 7/50
# 66/66 [==============================] - 6s 91ms/step - loss: 0.1594 - accuracy: 0.9515 - val_loss: 0.3194 - val_accuracy: 0.8462
# Epoch 8/50
# 66/66 [==============================] - 5s 81ms/step - loss: 0.0931 - accuracy: 0.9788 - val_loss: 0.2786 - val_accuracy: 0.8615
# Epoch 9/50
# 66/66 [==============================] - 6s 87ms/step - loss: 0.1348 - accuracy: 0.9515 - val_loss: 0.3471 - val_accuracy: 0.8462
# Epoch 10/50
# 66/66 [==============================] - 8s 118ms/step - loss: 0.1349 - accuracy: 0.9606 - val_loss: 0.2792 - val_accuracy: 0.8615
# Epoch 11/50
# 66/66 [==============================] - 6s 86ms/step - loss: 0.1143 - accuracy: 0.9545 - val_loss: 0.3258 - val_accuracy: 0.8462
# Epoch 12/50
# 66/66 [==============================] - 9s 130ms/step - loss: 0.1299 - accuracy: 0.9515 - val_loss: 0.2992 - val_accuracy: 0.8615
# Epoch 13/50
# 66/66 [==============================] - 7s 100ms/step - loss: 0.1229 - accuracy: 0.9515 - val_loss: 0.2899 - val_accuracy: 0.8615
# Epoch 14/50
# 66/66 [==============================] - 8s 120ms/step - loss: 0.1218 - accuracy: 0.9606 - val_loss: 0.3237 - val_accuracy: 0.8462
# Epoch 15/50
# 66/66 [==============================] - 5s 83ms/step - loss: 0.1599 - accuracy: 0.9485 - val_loss: 0.2873 - val_accuracy: 0.8615
# Epoch 16/50
# 66/66 [==============================] - 6s 96ms/step - loss: 0.1672 - accuracy: 0.9303 - val_loss: 0.2542 - val_accuracy: 0.8769
# Epoch 17/50
# 66/66 [==============================] - 5s 81ms/step - loss: 0.1484 - accuracy: 0.9424 - val_loss: 0.2704 - val_accuracy: 0.8615
# 66/66 [==============================] - 5s 81ms/step - loss: 0.1662 - accuracy: 0.9424 - val_loss: 0.3083 - val_accuracy: 0.8615
# Epoch 39/50
# 66/66 [==============================] - 6s 92ms/step - loss: 0.1355 - accuracy: 0.9606 - val_loss: 0.2636 - val_accuracy: 0.8923
# Epoch 40/50
# 66/66 [==============================] - 6s 83ms/step - loss: 0.1171 - accuracy: 0.9697 - val_loss: 0.2983 - val_accuracy: 0.8615
# Epoch 41/50
# 66/66 [==============================] - 8s 120ms/step - loss: 0.1329 - accuracy: 0.9485 - val_loss: 0.3131 - val_accuracy: 0.8462
# Epoch 42/50
# 66/66 [==============================] - 6s 92ms/step - loss: 0.1219 - accuracy: 0.9576 - val_loss: 0.3384 - val_accuracy: 0.8462
# Epoch 43/50
# 66/66 [==============================] - 7s 103ms/step - loss: 0.1233 - accuracy: 0.9606 - val_loss: 0.3189 - val_accuracy: 0.8462
# Epoch 44/50
# 66/66 [==============================] - 6s 94ms/step - loss: 0.1198 - accuracy: 0.9636 - val_loss: 0.3114 - val_accuracy: 0.8615
# Epoch 45/50
# 66/66 [==============================] - 8s 117ms/step - loss: 0.1235 - accuracy: 0.9576 - val_loss: 0.2687 - val_accuracy: 0.8615
# Epoch 46/50
# 66/66 [==============================] - 5s 82ms/step - loss: 0.1302 - accuracy: 0.9485 - val_loss: 0.2913 - val_accuracy: 0.8615
# Epoch 47/50
# 66/66 [==============================] - 7s 107ms/step - loss: 0.1135 - accuracy: 0.9545 - val_loss: 0.3080 - val_accuracy: 0.8462
# Epoch 48/50
# 66/66 [==============================] - 6s 91ms/step - loss: 0.1228 - accuracy: 0.9636 - val_loss: 0.3063 - val_accuracy: 0.8462
# Epoch 49/50
# 66/66 [==============================] - 5s 80ms/step - loss: 0.1406 - accuracy: 0.9455 - val_loss: 0.3071 - val_accuracy: 0.8462
# Epoch 50/50
# 66/66 [==============================] - 6s 85ms/step - loss: 0.1464 - accuracy: 0.9455 - val_loss: 0.3705 - val_accuracy: 0.8154

# %%
# 결과를 그래프로 그려보자
# 기존에 사용한 코드 그대로 이용해서 그래프를 그려보아라

fig = plt.figure()

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(history.history['loss'], color='r')
ax1.plot(history.history['val_loss'], color='b')

ax2.plot(history.history['accuracy'], color='r')
ax2.plot(history.history['val_accuracy'], color='b')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test 진행

# %%
# 테스트에 필요한 module import
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

# %%
# 저장된 모델 파일의 경로
saved_model_path = '/content/infantface_IDG_cnn_Eff_model.h5'

# 테스트할 이미지 경로 설정
test_image_path = '/content/drive/MyDrive/KOSA3/project/data/test_pos2.png'

# 모델 로드
loaded_model = load_model(saved_model_path)

# 이미지 불러오기 및 전처리
img = image.load_img(test_image_path, target_size=(150, 150))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
# 모델 예측
predictions = loaded_model.predict(img_array)

# 예측 결과 해석 및 출력
class_indices = np.argmax(predictions, axis=1)

# 각 클래스의 인덱스에 따른 레이블 설정 (positive, neutral, negative)
class_labels = ['positive', 'neutral', 'negative']
predicted_label = class_labels[class_indices[0]]

print(f"Predicted Class: {predicted_label}")
# Out:
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7bd92dd540d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# Predicted Class: negative
