# %% [markdown]
# # CNN 모델 구현

# %%
# 시작 전에 GPU로 바꿔주기

# %%
# Google Drive 접근 = 구글 마운트하기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 필요한 module import
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#  dir 불러오기
train_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/train'
validation_dir = '/content/drive/MyDrive/KOSA3/project/data/infantface/valid'

# %% [markdown]
# ## ImageDataGenerator 만들기(rescale만 사용)

# %%
# ImageDataGenerator 객체 생성

train_datagen = ImageDataGenerator(rescale=1/255) # 0 or 1의 값이 나올 수 있도록 255로 나누어 준다
validation_datagen=ImageDataGenerator(rescale=1/255)


# ImageDataGenerator 객체 세부 설정
# 넌 이렇게 동작해야해! 라고 세부 세팅을 해준다

train_generator = train_datagen.flow_from_directory( # train_datagen.flow_from_directory() 특정 폴더로부터 generator을 뽑아내는 객체를 하나 만든다
    train_dir, # target directory
    classes=['positive', 'neutral', 'negative'], # train 안에 있는 폴더를 내가 원하는 순서대로 준다 (positive -> neutral -> negative)
                                                 # label(target) 지정, list의 순서대로 지정하기!
                                                 # 만약 생략되면 폴더 순서는 오름차순으로 지정된다.
    target_size=(150, 150), #image resize
    batch_size=5, # 한번에 20개의 이미지를 가져온다
                  # label에 상관없이 이미지를 가져온다
    class_mode='categorical' # 다중분류 : categorical, 이진분류 : binary
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    classes=['positive', 'neutral', 'negative'],
    target_size=(150, 150), # 평가 데이터이기 떄문에 size를 똑같이 가져와야 한다
    batch_size=5,
    class_mode='categorical'
)
# Out:
# Found 380 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.

# %% [markdown]
# ## CNN 모델 구현 (pretrained-model : VGG16)

# %%
# Model을 만들어야 해요!
# Pretrained Network을 가져다가 사용할꺼예요!

from tensorflow.keras.applications import VGG16

pretrained_model = VGG16(weights='imagenet',
                   include_top=False,
                   input_shape=(150,150,3))

# Convolution Layer 동결
pretrained_model.trainable = False

model = Sequential()

# 우리 model에 pretrained network의 feature extraction을 가져다가 놓아요!
model.add(pretrained_model)

model.add(Flatten(input_shape=(4*4*512,)))

model.add(Dense(units=256,
                activation='relu'))

model.add(Dropout(rate=0.5))

model.add(Dense(units=3,
                activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 16812867 (64.14 MB)
# Trainable params: 2098179 (8.00 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# Model 학습 설정하고 학습을 진행

# model checkpoint 확인
model_cp = ModelCheckpoint(filepath='infantface_checkpoint.ckpt', # 임시로 제공 받은 runtime disk에 파일이 만들어진다. 계산된 가중치를 저장해놓자
                           save_weights_only=True,
                           save_best_only=True,
                           monitor='val_loss',
                           verbose=1)

# model earlystopping 확인(조기 종료는 언제할까요?)
model_es = EarlyStopping(monitor='val_loss',
                         patience=5,
                         verbose=1,
                         restore_best_weights=True)


model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_generator,
                    steps_per_epoch=76, #train 총 이미지 나누기 5
                    epochs=30,
                    validation_data=validation_generator,
                    validation_steps=12, #val 데이터 총 이미지 나누기 5
                    verbose=1,
                    callbacks=[model_cp])

model.save('./infantface_IDG_cnn_VGG16_model.h5')
# Out:
# Epoch 1/30
# 76/76 [==============================] - ETA: 0s - loss: 9.4313e-05 - accuracy: 1.0000
# Epoch 1: val_loss improved from inf to 0.06749, saving model to infantface_checkpoint.ckpt
# 76/76 [==============================] - 4s 36ms/step - loss: 9.4313e-05 - accuracy: 1.0000 - val_loss: 0.0675 - val_accuracy: 0.9500
# Epoch 2/30
# 75/76 [============================>.] - ETA: 0s - loss: 5.7865e-04 - accuracy: 1.0000
# Epoch 2: val_loss did not improve from 0.06749
# 76/76 [==============================] - 2s 32ms/step - loss: 5.7104e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9500
# Epoch 3/30
# 74/76 [============================>.] - ETA: 0s - loss: 9.3324e-05 - accuracy: 1.0000
# Epoch 3: val_loss did not improve from 0.06749
# 76/76 [==============================] - 2s 31ms/step - loss: 9.2750e-05 - accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9667
# Epoch 4/30
# 75/76 [============================>.] - ETA: 0s - loss: 1.0086e-04 - accuracy: 1.0000
# Epoch 4: val_loss improved from 0.06749 to 0.02149, saving model to infantface_checkpoint.ckpt
# 76/76 [==============================] - 3s 33ms/step - loss: 9.9693e-05 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 5/30
# 76/76 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9974
# Epoch 5: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 0.0055 - accuracy: 0.9974 - val_loss: 0.4765 - val_accuracy: 0.9167
# Epoch 6/30
# 76/76 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9974
# Epoch 6: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.0433 - val_accuracy: 0.9667
# Epoch 7/30
# 76/76 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 7: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9500
# Epoch 8/30
# 75/76 [============================>.] - ETA: 0s - loss: 1.2907e-04 - accuracy: 1.0000
# Epoch 8: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 32ms/step - loss: 1.2744e-04 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9500
# Epoch 9/30
# 76/76 [==============================] - ETA: 0s - loss: 1.3410e-04 - accuracy: 1.0000
# Epoch 9: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 1.3410e-04 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9500
# Epoch 10/30
# 75/76 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 10: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 32ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9500
# Epoch 11/30
# 74/76 [============================>.] - ETA: 0s - loss: 2.4774e-04 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 2.4127e-04 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9667
# Epoch 12/30
# 76/76 [==============================] - ETA: 0s - loss: 8.5379e-05 - accuracy: 1.0000
# Epoch 12: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 8.5379e-05 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9500
# Epoch 13/30
# 74/76 [============================>.] - ETA: 0s - loss: 4.0275e-05 - accuracy: 1.0000
# Epoch 13: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 32ms/step - loss: 3.9216e-05 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 0.9500
# Epoch 14/30
# 74/76 [============================>.] - ETA: 0s - loss: 9.6807e-05 - accuracy: 1.0000
# Epoch 14: val_loss did not improve from 0.02149
# 76/76 [==============================] - 3s 34ms/step - loss: 9.7359e-05 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9500
# Epoch 15/30
# 76/76 [==============================] - ETA: 0s - loss: 1.8999e-04 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 30ms/step - loss: 1.8999e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9500
# Epoch 16/30
# 76/76 [==============================] - ETA: 0s - loss: 7.3976e-05 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 30ms/step - loss: 7.3976e-05 - accuracy: 1.0000 - val_loss: 0.0936 - val_accuracy: 0.9500
# Epoch 17/30
# 76/76 [==============================] - ETA: 0s - loss: 1.0629e-04 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 30ms/step - loss: 1.0629e-04 - accuracy: 1.0000 - val_loss: 0.0569 - val_accuracy: 0.9667
# Epoch 18/30
# 75/76 [============================>.] - ETA: 0s - loss: 1.1172e-04 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 1.1025e-04 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9500
# Epoch 19/30
# 76/76 [==============================] - ETA: 0s - loss: 4.9793e-05 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 32ms/step - loss: 4.9793e-05 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 0.9500
# Epoch 20/30
# 75/76 [============================>.] - ETA: 0s - loss: 1.7162e-04 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 32ms/step - loss: 1.6937e-04 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9667
# Epoch 21/30
# 75/76 [============================>.] - ETA: 0s - loss: 2.9895e-04 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 2.9755e-04 - accuracy: 1.0000 - val_loss: 0.3515 - val_accuracy: 0.9333
# Epoch 22/30
# 76/76 [==============================] - ETA: 0s - loss: 2.5812e-04 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 2.5812e-04 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9667
# Epoch 23/30
# 74/76 [============================>.] - ETA: 0s - loss: 8.4031e-05 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 8.1821e-05 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9667
# Epoch 24/30
# 75/76 [============================>.] - ETA: 0s - loss: 2.9510e-05 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 2.9152e-05 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9667
# Epoch 25/30
# 76/76 [==============================] - ETA: 0s - loss: 2.8132e-05 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 32ms/step - loss: 2.8132e-05 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9667
# Epoch 26/30
# 76/76 [==============================] - ETA: 0s - loss: 7.7036e-06 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 32ms/step - loss: 7.7036e-06 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9667
# Epoch 27/30
# 75/76 [============================>.] - ETA: 0s - loss: 2.3585e-05 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 2.3274e-05 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9667
# Epoch 28/30
# 75/76 [============================>.] - ETA: 0s - loss: 1.1221e-05 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 1.1074e-05 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9667
# Epoch 29/30
# 75/76 [============================>.] - ETA: 0s - loss: 7.2972e-05 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 7.2048e-05 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9667
# Epoch 30/30
# 75/76 [============================>.] - ETA: 0s - loss: 9.2538e-05 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.02149
# 76/76 [==============================] - 2s 31ms/step - loss: 9.1368e-05 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9500

# %%
# 결과 그래프를 그려보아요!

import matplotlib.pyplot as plt

fig = plt.figure()

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(history.history['loss'], color='r')
ax1.plot(history.history['val_loss'], color='b')

ax2.plot(history.history['accuracy'], color='r')
ax2.plot(history.history['val_accuracy'], color='b')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Test

# %%
# 테스트에 필요한 module import
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

# %%
# 저장된 모델 파일의 경로
# saved_model_path = '/content/saved된 모델이름.h5' # model을 학습시킬 때 마지막에 model.save('저장된 모델 이름')코드 안에 있는 모델 이름을 적어주시면 됩니다
saved_model_path = '/content/infantface_IDG_cnn_VGG16_model.h5'

# 테스트할 이미지 경로 설정
test_image_path = '/content/drive/MyDrive/KOSA3/project/data/baby6.png'

# 모델 로드
loaded_model = load_model(saved_model_path)

# 이미지 불러오기 및 전처리
img = image.load_img(test_image_path, target_size=(150, 150)) # 위에서 우리가 저장한 target_size와 같은 크기로 주시면 돼요!
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0) # 경우에 따라 axis값이 달라집니다
img_array = preprocess_input(img_array)

# %%
# 모델 예측
predictions = loaded_model.predict(img_array)

# 예측 결과 해석 및 출력
class_indices = np.argmax(predictions, axis=1)

# 각 클래스의 인덱스에 따른 레이블 설정 (positive, neutral, negative)
class_labels = ['positive', 'neutral', 'negative']
predicted_label = class_labels[class_indices[0]]

print(f"Predicted Class: {predicted_label}")
# Out:
# 1/1 [==============================] - 0s 134ms/step
# Predicted Class: positive
